# %% [markdown]
# # Model I/O

# %% [markdown]
# ## Language Model

# %%
from langchain.llms import OpenAI

# %%
# The LLM objects take string as input and output string
llm = OpenAI(model_name="gpt-3.5-turbo-instruct", temperature=0.4)

# %%
huamn_text = "What should I do if I wish to analyse customer reviews"

# %%
llm.invoke(huamn_text)
# Out:
# '\n\n1. Define your goals: Before starting the analysis, it is important to clearly define your goals and what you hope to achieve from the analysis. This will help guide your approach and ensure that you are focusing on the most relevant aspects of the customer reviews.\n\n2. Choose a platform: There are many platforms available for analyzing customer reviews, such as social media monitoring tools, sentiment analysis tools, and text analysis tools. Choose a platform that best fits your needs and budget.\n\n3. Collect the data: The first step in analyzing customer reviews is to collect the data. This can be done by manually going through each review or by using a data scraping tool to gather reviews from various sources.\n\n4. Clean and organize the data: Once you have collected the data, it is important to clean and organize it. This involves removing any irrelevant or duplicate reviews and categorizing the reviews based on different criteria such as product, service, or sentiment.\n\n5. Use sentiment analysis: Sentiment analysis is a powerful tool that can help you understand the overall sentiment of customer reviews. This involves using natural language processing techniques to identify and categorize the emotions expressed in the reviews, such as positive, negative, or neutral.\n\n6. Identify common themes: Look for common themes or topics that are mentioned'

# %% [markdown]
# ## Chat Model
# Takes series of messages

# %%
from langchain.chat_models import ChatOpenAI
from langchain.schema import SystemMessage, HumanMessage

# %%
# The ChatModel objects take a list of messages as input and output a message.
chat_model = ChatOpenAI(temperature=0.4)

# %%
chat_model(
    [
        SystemMessage(content="You are a Bot to make concise and actionable response to users")
        , HumanMessage(content=huamn_text)
    ]
)
# Out:
# AIMessage(content='If you wish to analyze customer reviews, here are a few steps you can follow:\n\n1. Collect the data: Gather customer reviews from various sources such as online platforms, social media, surveys, or feedback forms. Make sure you have a substantial amount of data for meaningful analysis.\n\n2. Define your objectives: Determine what you want to achieve through the analysis. Are you looking to identify common themes, sentiment analysis, or extract specific insights? Clearly define your goals to guide your analysis.\n\n3. Preprocess the data: Clean the data by removing irrelevant information, such as duplicates or spam. Normalize the text by converting it to lowercase, removing punctuation, and removing stop words (common words like "and," "the," etc.).\n\n4. Apply sentiment analysis: Use natural language processing techniques to determine the sentiment of each review. Assign positive, negative, or neutral sentiment scores to each review to understand overall customer sentiment.\n\n5. Identify themes: Use techniques like text mining or topic modeling to identify common themes or topics in the reviews. This will help you understand the main concerns, preferences, or issues raised by customers.\n\n6. Quantify and visualize the data: Analyze the data quantitatively by calculating metrics like average sentiment scores, frequency of themes, or sentiment distribution. Visualize the results using charts, word clouds, or other visual representations for better understanding.\n\n7. Extract actionable insights: Based on the analysis, identify key insights and patterns that can guide decision-making. These insights can help improve products, services, or customer experiences.\n\n8. Monitor and track changes: Continuously analyze customer reviews to track changes over time and identify emerging trends or issues. This will help you stay proactive and responsive to customer feedback.\n\nRemember, customer reviews are a valuable source of information, and analyzing them can provide valuable insights for improving your business.')

# %% [markdown]
# ## Prompt
# use template and input variables

# %% [markdown]
# contains content info

# %%
from langchain.prompts import PromptTemplate

my_prompt_template = PromptTemplate.from_template("What should I do if I wish to {things_wish_to_do}")
my_prompt_template.format(things_wish_to_do="learn skiing")
# Out:
# 'What should I do if I wish to learn skiing'

# %%
my_prompt_template.format(things_wish_to_do="understand why customers are unhappy with service")
# Out:
# str

# %% [markdown]
# contains message info

# %%
from langchain.prompts.chat import ChatPromptTemplate

sys_temp = "You are a Bot to make {res_style_1} and {res_style_2} response to {user_role} in {word_limit} words"
human_temp = "{human_text}"

my_chat_prompt_template = ChatPromptTemplate.from_messages(
    [
        ("system", sys_temp)
        , ("human", human_temp)
    ]
)

human_content = my_prompt_template.format(things_wish_to_do="understand why customers are unhappy with service")

chat_prompt = my_chat_prompt_template.format_messages(res_style_1="concise"
                                                      , res_style_2="actionable"
                                                      , user_role="Data Scientist"
                                                      , word_limit="200"
                                                      , human_text=human_content)
# Out:
# [SystemMessage(content='You are a Bot to make concise and actionable response to Data Scientist in 200 words'),
#  HumanMessage(content='What should I do if I wish to understand why customers are unhappy with service')]

# %% [markdown]
# Output parser

# %% [markdown]
# put together

# %%
chain = chat_prompt | chat_model |

# %% [markdown]
# # Retrieval

# %% [markdown]
# ## Document Loader

# %%
import pandas as pd
from langchain.document_loaders import DataFrameLoader

# %%
df = pd.read_csv("../data/ms_sample.csv")

# %%
df.columns
# Out:
# Index(['ID', 'Q1_OSAT', 'Comments'], dtype='object')

# %%
df_loader = DataFrameLoader(df, page_content_column="Comments")
df_loader.load()
# Out:
# [Document(page_content='Courteous people who seem to care about the customer', metadata={'ID': 1, 'Q1_OSAT': 10}),
#  Document(page_content='My concern was handled quickly and professionally by a caring individual who was knowledgeable in the area of my needs. They asked if there was anything else they could do to assist me, but they had already solved my problem.', metadata={'ID': 36, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 70, 'Q1_OSAT': 10}),
#  Document(page_content='I had the GREATEST customer service and interaction with Deja!! She was very helpful and knowledgeable. She smiled and shook my hand.', metadata={'ID': 107, 'Q1_OSAT': 10}),
#  Document(page_content='I felt someone was trying to trick me into giving personal info and saying they were from XXX. I did report it and I also hung up on this man.', metadata={'ID': 111, 'Q1_OSAT': 10}),
#  Document(page_content="My issue which included transferring finds from one account to another's was easily managed with all security protocols. The XXX representative was friendly , personable, and professional. We also discussed a CD option. Great customer service.", metadata={'ID': 120, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 123, 'Q1_OSAT': 10}),
#  Document(page_content='My questions were answered.', metadata={'ID': 124, 'Q1_OSAT': 10}),
#  Document(page_content='Rep was friendly, respectful,courteous and knowledgeable and answered my questions quickly and thoroughly. She immediately knew where to go to find the answer to the problem.', metadata={'ID': 132, 'Q1_OSAT': 10}),
#  Document(page_content='We Never discussed where, in my accounts the credit line would be held or how I can access it. I called back with these questions. I felt like Mariah pushed me to answer questions immediately on the phone about specific financial totals off the top of my head without time to access documents. This may have worked against me. She was interested in closing the deal ASAP.', metadata={'ID': 138, 'Q1_OSAT': 6}),
#  Document(page_content='My call was answered promptly - no hold even though it was first thing in the morning. My question about Bill Pay was answered quickly determining the date my payment went out to a credit card company. The technician who helped me even quickly provided a letter of proof of payment to send to the credit card company showing the bill was paid on time. This was all handled in a matter of minutes. Quick prompt efficient, and super kind service! Thank you', metadata={'ID': 152, 'Q1_OSAT': 10}),
#  Document(page_content='I made the call to find out how to make an appointment with a representative at Jackson Creek. The Ent agent I spoke with guided me through the process on your website, I got my appointment, and left the call a happy member.', metadata={'ID': 159, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 194, 'Q1_OSAT': 10}),
#  Document(page_content='Quick answer to my question', metadata={'ID': 200, 'Q1_OSAT': 10}),
#  Document(page_content="I usually have good experiences when i talk to Ent CU personnel. I haven't had occasion to be unhappy with Ent personnel that i can remember.", metadata={'ID': 202, 'Q1_OSAT': 10}),
#  Document(page_content='To confirm wire transfer was received and instructions were followed.', metadata={'ID': 204, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 255, 'Q1_OSAT': 10}),
#  Document(page_content='person was helpful and polite and put me in contact with the people I needed to speak with', metadata={'ID': 285, 'Q1_OSAT': 10}),
#  Document(page_content='Handle the situation for me and answered all my questions', metadata={'ID': 288, 'Q1_OSAT': 10}),
#  Document(page_content='Customer rep I spoke with was very courteous and patient while assisting me with the questions I had. Also, made some great recommendations about my accounts.', metadata={'ID': 295, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 303, 'Q1_OSAT': 10}),
#  Document(page_content="Individual helped me figure out an issue. Was XXX's or was it T-Mobile's. With the information provided I was able to quickly identify that the issue was with T-mobile and was able to fix it.", metadata={'ID': 326, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 328, 'Q1_OSAT': 8}),
#  Document(page_content='It was what I needed', metadata={'ID': 335, 'Q1_OSAT': 10}),
#  Document(page_content='I received all the information I needed to make a really good decision on my account', metadata={'ID': 344, 'Q1_OSAT': 10}),
#  Document(page_content='The amount I can transfer at one time.', metadata={'ID': 347, 'Q1_OSAT': 10}),
#  Document(page_content="I was rushed during the phone call. Didn't take the time to listen to me.", metadata={'ID': 354, 'Q1_OSAT': 6}),
#  Document(page_content="The rep was very helpful. I just needed info snout moving funds from my account to another XXX members account. I've done it and wasn't sure I could do it over the phone.", metadata={'ID': 361, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 369, 'Q1_OSAT': 10}),
#  Document(page_content='Whenever I call, everyone is so polite and always ready to help.', metadata={'ID': 393, 'Q1_OSAT': 10}),
#  Document(page_content='The young lady on the phone was so polite. Rwilling to help me. With all my questions. And I really appreciate people that look out for the senior citizens. So thank you again it was a pleasure doing business with you', metadata={'ID': 394, 'Q1_OSAT': 10}),
#  Document(page_content='Questions were answered quickly and accurately.', metadata={'ID': 396, 'Q1_OSAT': 10}),
#  Document(page_content='Ent has always been great. They help in every way possible, no matter what the situation is.', metadata={'ID': 397, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 413, 'Q1_OSAT': 10}),
#  Document(page_content='I have been a member for a half century and have been extremely satisfied with the service', metadata={'ID': 427, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 439, 'Q1_OSAT': 10}),
#  Document(page_content="Direct access to an English speaking human. Simple solution to my problem. Constructive usage of my time. However, after 3 minutes more of my time to give you this rating. I don't like wasting my time further. Goodbye", metadata={'ID': 456, 'Q1_OSAT': 10}),
#  Document(page_content="I called about a potential fraud charge and got that clarified very quickly. The attendant immediately put in a case for the charges and gave me an ETA for when they'll reach out about it later.", metadata={'ID': 472, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 496, 'Q1_OSAT': 10}),
#  Document(page_content='They couldnâ€™t find a Bank near me in Dayton Ohio to tx a check', metadata={'ID': 505, 'Q1_OSAT': 8}),
#  Document(page_content='forgot my keys at the Canon City CO branch. The customer representative was extremely helpful in putting me in touch with the branch. Found my keys and they asked me several question to make sure the keys were mine,', metadata={'ID': 539, 'Q1_OSAT': 10}),
#  Document(page_content='The customer rep was very knowledgable and kind.. She answered my concern very quickly. Unlike the last person I dealt with at the Canon office who was horribly patronizing!', metadata={'ID': 540, 'Q1_OSAT': 9}),
#  Document(page_content='nan', metadata={'ID': 555, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 585, 'Q1_OSAT': 10}),
#  Document(page_content='My question was answered promptly.', metadata={'ID': 587, 'Q1_OSAT': 10}),
#  Document(page_content='Had a super detail oriented service member, walked through all the steps and even gave me great suggestions to help resolve the issue. Best credit union hands down', metadata={'ID': 625, 'Q1_OSAT': 10}),
#  Document(page_content='Zach was extremely helpful, professional and pleasant to work with. He took care of the reason I called with efficiency and introduced a great perk for continuing doing business with Ent.', metadata={'ID': 641, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 643, 'Q1_OSAT': 9}),
#  Document(page_content='Great customer service so compassionate, very understanding. Love iENT from the bottom of my heart.', metadata={'ID': 650, 'Q1_OSAT': 10}),
#  Document(page_content='The representative was very knowledgeable and helpful. She understood what I wanted and took care of it.', metadata={'ID': 660, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 666, 'Q1_OSAT': 10}),
#  Document(page_content='Everyone was very helpful especially Jessica', metadata={'ID': 671, 'Q1_OSAT': 10}),
#  Document(page_content="'nice1 easy to talk", metadata={'ID': 679, 'Q1_OSAT': 10}),
#  Document(page_content='Friendly, caring, knowledgeable', metadata={'ID': 682, 'Q1_OSAT': 9}),
#  Document(page_content="The problem wasn't resolved but Suzanna tried!", metadata={'ID': 683, 'Q1_OSAT': 8}),
#  Document(page_content='Every interaction with them is fabulous. Even living outside Colorado they are so easy to get ahold of and help resolved your issue as quickly as possible. Customer service is outstanding.', metadata={'ID': 729, 'Q1_OSAT': 10}),
#  Document(page_content='Brian was friendly and did what I asked and verified it and gave me the balances of both accounts worked with. I also appreciated that he understood my passcode with no problems. I am almost always satisfied with the telephone employees at XXX.', metadata={'ID': 738, 'Q1_OSAT': 10}),
#  Document(page_content='Paula was friendly and efficient', metadata={'ID': 739, 'Q1_OSAT': 10}),
#  Document(page_content="Because sometimes I have no idea when a pending purchase will post, I got hit with three overdraft charges in one day. The lady was nice, but said there was nothing she could do to reverse $90 in charges. Left a bad taste in my mouth because I've been a customer for 8ish years, and am hitting a particularly low point financially.", metadata={'ID': 751, 'Q1_OSAT': 3}),
#  Document(page_content='Got me to the correct person immediately.', metadata={'ID': 755, 'Q1_OSAT': 10}),
#  Document(page_content='A very kind and caring gentleman named Sal, took care of all my concerns about a fraudulent charge. He reassured me that everything would be taken care of and was so nice concerning my entire situation. J Jones', metadata={'ID': 759, 'Q1_OSAT': 10}),
#  Document(page_content='Caring, friendly, very efficient', metadata={'ID': 760, 'Q1_OSAT': 10}),
#  Document(page_content='Be glad to: 7/26/2023, I called Ent Credit Union for information and help. I spoke with Christina. She said she will have Charleen call me back regarding my Updating Account Beneficiaries form and questions. She said Charleen will know more about it. She said she sent Charleen a message and she will contact me. Well, I am still waiting for this call/contact. Now I am considering if I should keep my account with Ent. I have been a loyal customer for many, many years and deserve better. I now know my little money means nothing to you but hoped my loyalty does. I am still waiting to hear from Ent regarding my situation. Yes, I am disappointed in the service. After all these years with Ent, this is sad. I was just thinking about starting an allotment to increase my account. Now I am considering if I should even keep the account with you and transfer my funds to a more supportive Credit Union.', metadata={'ID': 765, 'Q1_OSAT': 2}),
#  Document(page_content='Agent was rude/unfriendly--in a bad mood', metadata={'ID': 783, 'Q1_OSAT': 2}),
#  Document(page_content='Be more willing to lend!', metadata={'ID': 788, 'Q1_OSAT': 8}),
#  Document(page_content='nan', metadata={'ID': 789, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 813, 'Q1_OSAT': 9}),
#  Document(page_content='Person I spoke with took time to explain my XXX mbrship in detail. I had no idea the difference between my XXX Visa card and my mbrship and funds I had no idea I had.', metadata={'ID': 816, 'Q1_OSAT': 9}),
#  Document(page_content='I had to get a medallion signature and my questions were answered, and an appointment was made for within 24 hours.', metadata={'ID': 821, 'Q1_OSAT': 10}),
#  Document(page_content='Representative was professionally and pleasant but not really answering my question', metadata={'ID': 822, 'Q1_OSAT': 5}),
#  Document(page_content='nan', metadata={'ID': 830, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 839, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 843, 'Q1_OSAT': 10}),
#  Document(page_content='The individual I spoke with expressed concern for my conflict, and asked pertinent questions; however, the end result was not as expected, and after I made another inquiry, I have been ignored.', metadata={'ID': 862, 'Q1_OSAT': 7}),
#  Document(page_content='nan', metadata={'ID': 872, 'Q1_OSAT': 10}),
#  Document(page_content='Extremely friendly, and given the information I needed', metadata={'ID': 874, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 913, 'Q1_OSAT': 10}),
#  Document(page_content='I was able to get my question answered and the situation resolved. Monica was really helpful giving me the advice I needed.', metadata={'ID': 922, 'Q1_OSAT': 8}),
#  Document(page_content='The person I spoke with was polite and helpful. He knew how to fix the problem I was calling about and communicated clearly with me the timeline on how long it would take to be resolved.', metadata={'ID': 925, 'Q1_OSAT': 9}),
#  Document(page_content='Excellent customer service', metadata={'ID': 948, 'Q1_OSAT': 10}),
#  Document(page_content='The representative was friendly, helpful and efficient.', metadata={'ID': 954, 'Q1_OSAT': 10}),
#  Document(page_content='the customer service representative was very helpful and was able to take care of all my needs asked her if she could order me my checks and also send me register log since l use my debit card 80 % if the time and post every time l use my card l have had my acct with XXX for 30+ years and am very happy with the service and that everytime l do need assistance the service staff know what their doing have never in all the years had a problem so thank you for the Best Service all these years', metadata={'ID': 955, 'Q1_OSAT': 10}),
#  Document(page_content='I was able to access my safe deposit box which was my goal. However, I had to wait for another customer that had no key for their box. It had to be drilled so their issue caused me delay. They shouldâ€™ve made an appointment given their situation, I was told I could walk in without an appointment little did I know', metadata={'ID': 957, 'Q1_OSAT': 6}),
#  Document(page_content='They were very helpful.', metadata={'ID': 959, 'Q1_OSAT': 10}),
#  Document(page_content='The very nice lady that assisted me resolved the issues and got me on my way as fast as she could. It was an awesome experience!', metadata={'ID': 960, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 970, 'Q1_OSAT': 10}),
#  Document(page_content='Very friendly member who answered the phone. Did her best to help me.', metadata={'ID': 1011, 'Q1_OSAT': 8}),
#  Document(page_content='I am always made to feel as if I am your only customer. My contact did not rush me, explained everything and made sure I was good before ending the call.', metadata={'ID': 1026, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1030, 'Q1_OSAT': 10}),
#  Document(page_content="I made a mistake during a time I had severe backache and wasn't thinking further than the pain, and I transferred some money from checking to savings to prevent Liberty from taking an early payment but forgot that I had written a very rare check for the DMV for my car registration. The DMV got my check quickly and cashed it before I remembered to put the money back, and not having an internet connection didn't help. I was helped by a nice woman but she couldn't waive the courtesy charge of $30.", metadata={'ID': 1032, 'Q1_OSAT': 8}),
#  Document(page_content='Very friendly and patient with me because I am hard of hearing.', metadata={'ID': 1033, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1035, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1036, 'Q1_OSAT': 5}),
#  Document(page_content='Customer service was very clear and informative to my situation', metadata={'ID': 1051, 'Q1_OSAT': 10}),
#  Document(page_content='I was attempting to gather the facts on a very rare NSF action. The paper record was not as clear and easy to understand as I had hoped. Once the facts were uncovered, the actions were adjusted appropriately and responsibly.', metadata={'ID': 1058, 'Q1_OSAT': 8}),
#  Document(page_content='I am not kept waiting for lengthy periods before my call is answered. The agents are professional and my issues are resolved in one call, for the most part.', metadata={'ID': 1061, 'Q1_OSAT': 9}),
#  Document(page_content='my question was resolved.', metadata={'ID': 1064, 'Q1_OSAT': 10}),
#  Document(page_content='The agent seemed to be very knowledgeable. And answered all my questions. She was also very pleasant.', metadata={'ID': 1085, 'Q1_OSAT': 10}),
#  Document(page_content='Patient and informed person on phone.', metadata={'ID': 1086, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1109, 'Q1_OSAT': 9}),
#  Document(page_content='nan', metadata={'ID': 1113, 'Q1_OSAT': 8}),
#  Document(page_content='nan', metadata={'ID': 1185, 'Q1_OSAT': 9}),
#  Document(page_content='Information about use of my account was provided', metadata={'ID': 1191, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1199, 'Q1_OSAT': 10}),
#  Document(page_content='The rep was extremely friendly, bubbly, upbeat, empathetic, personable and basically had all the traits every company should look for in their customer service employees. Ironically, she wasnâ€™t able to help me due to ENTâ€™s NSF policy, but she still made me happy.', metadata={'ID': 1200, 'Q1_OSAT': 10}),
#  Document(page_content='In VERY little time, I was connected with a knowledgeable, capable person who understood my problem immediately and gave me clear, correct instructions on how to do what needed to be done--and it turns out that Ent had already built in an extraordinarily easy way to do it right from my account page!', metadata={'ID': 1216, 'Q1_OSAT': 10}),
#  Document(page_content='The Channel one that helped me with very polite and listen to what I had to say and found where the mistake was.', metadata={'ID': 1218, 'Q1_OSAT': 10}),
#  Document(page_content='The service was amazing', metadata={'ID': 1219, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1220, 'Q1_OSAT': 1}),
#  Document(page_content='all people I talk to are courteous and knowledgeable to my concerns', metadata={'ID': 1233, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1238, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1252, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1267, 'Q1_OSAT': 10}),
#  Document(page_content='Destiny only took a couple of minutes to figure out why and explained to me why a deposit was rejected.', metadata={'ID': 1270, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1276, 'Q1_OSAT': 10}),
#  Document(page_content='My wife has been a member of XXX for 35 years and we have always a terrific dealings with them. The service professionals are kind, gracious and helpful. As far as we are concerned, XXX will be our Credit Union for life.', metadata={'ID': 1284, 'Q1_OSAT': 10}),
#  Document(page_content='The person was helpful. That was especially true in contrast to the previous person I called, who was not helpful at all!', metadata={'ID': 1285, 'Q1_OSAT': 10}),
#  Document(page_content='Great service', metadata={'ID': 1302, 'Q1_OSAT': 10}),
#  Document(page_content='She was pleasant and patient.Very helpful.', metadata={'ID': 1304, 'Q1_OSAT': 10}),
#  Document(page_content='Very helpful and a willingness to resolve my problem.', metadata={'ID': 1307, 'Q1_OSAT': 10}),
#  Document(page_content='When I call in the help line people have quick responses, great attitudes. when i have left messages for the loan department they are quick with call backs. in the loan dept better sugestions have been brought to my attention on better ways to go about things.', metadata={'ID': 1315, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1324, 'Q1_OSAT': 10}),
#  Document(page_content='24 hours later I have received no call and no action on my account.', metadata={'ID': 1336, 'Q1_OSAT': 2}),
#  Document(page_content='nan', metadata={'ID': 1337, 'Q1_OSAT': 10}),
#  Document(page_content='Everytime I call in with a problem it always get solved :)', metadata={'ID': 1346, 'Q1_OSAT': 10}),
#  Document(page_content="I appear to be getting a run-around about two missing deposits, each $1500. I was told by XXX to collect and provide a Electronic Trace Number for the two missing deposits. I called Ent and gave them the trace numbers and was told that XXX could not confirm that XXX received the two deposits. The person that I spoke with at XXX was unsure how to locate the details about the missing deposits and put me on hold several times to confirm with a co-worker. The source of the two deposits confirmed that XXX had received them. It appears that XXX received the two deposits and deposited them, but not my account. I'm out $3000 and staff at XXX so far has given me a run-round and each time reports that I need to collect something else.", metadata={'ID': 1355, 'Q1_OSAT': 1}),
#  Document(page_content='Employeeâ€™s are always courteous and helpful', metadata={'ID': 1361, 'Q1_OSAT': 10}),
#  Document(page_content='Customerservices', metadata={'ID': 1394, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1407, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1413, 'Q1_OSAT': 10}),
#  Document(page_content='Too long on hold for a simple answer that is not on the website.', metadata={'ID': 1423, 'Q1_OSAT': 6}),
#  Document(page_content='nan', metadata={'ID': 1424, 'Q1_OSAT': 10}),
#  Document(page_content='The customer service person was very professional', metadata={'ID': 1428, 'Q1_OSAT': 10}),
#  Document(page_content='The policy that XXX seems to have when a customer wants to redeem a CD that is maturing is unreasonable. A request to have a check sent to the customer was denied.Very hard to understand and not customer service.', metadata={'ID': 1438, 'Q1_OSAT': 1}),
#  Document(page_content='I had an issue with my credit/debit card and was able to get resolved quickly and to my satisfaction.', metadata={'ID': 1451, 'Q1_OSAT': 10}),
#  Document(page_content='I got most of the information that I requested.', metadata={'ID': 1459, 'Q1_OSAT': 8}),
#  Document(page_content='Person was knowledgeable and patient', metadata={'ID': 1460, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1464, 'Q1_OSAT': 10}),
#  Document(page_content='There was an issue and once transferred the call went dead, happened twice. Finally, I got someone to not transfer without making sure the other side was there.', metadata={'ID': 1467, 'Q1_OSAT': 5}),
#  Document(page_content='While everyone was helpful and friendly, my call got dropped once and I had to call back in and explain everything to a new person. I waited a few min to see if the first person would call back, but they did not.', metadata={'ID': 1472, 'Q1_OSAT': 8}),
#  Document(page_content='i was extremely satisfied when I needed, not only a Medallion Stamp, but, a Notary stamp. This young man who works in the Broomfield, CO Credit Union took care of everything!.. And, in minutes!! I love this credit union.. they are always a caring staff. Thank you!', metadata={'ID': 1473, 'Q1_OSAT': 10}),
#  Document(page_content="I live in Florida and to get a new debt card if stolen or destroyed it takes 10 to fourteen days or pay 50 dollars for Express delivery I know people who have credit union outside of Florida who don't have this problem", metadata={'ID': 1477, 'Q1_OSAT': 4}),
#  Document(page_content='She was kind, she did a good job trying to solve my problems dns eek information to provide that could be helpful. She laughed a few times to lighten the mood- I was impressed, despite not fully getting the answer I wanted- she was gifted at saying no in a way I could tolerate.', metadata={'ID': 1481, 'Q1_OSAT': 10}),
#  Document(page_content='Amazing service', metadata={'ID': 1492, 'Q1_OSAT': 10}),
#  Document(page_content='They fixed my issue!', metadata={'ID': 1493, 'Q1_OSAT': 10}),
#  Document(page_content='Phone rep. came across as condescending.', metadata={'ID': 1512, 'Q1_OSAT': 5}),
#  Document(page_content="The customer service is always excellent. I wasn't on hold for a long time and the person who answered the call was pleasant and helpful.", metadata={'ID': 1513, 'Q1_OSAT': 10}),
#  Document(page_content='Quick, competent service', metadata={'ID': 1556, 'Q1_OSAT': 10}),
#  Document(page_content='The problem was not resolved.', metadata={'ID': 1571, 'Q1_OSAT': 8}),
#  Document(page_content='My questions were answered.', metadata={'ID': 1589, 'Q1_OSAT': 10}),
#  Document(page_content='I waited almost 30 minutes to get my new debit card after I saw the casher.', metadata={'ID': 1596, 'Q1_OSAT': 9}),
#  Document(page_content='nan', metadata={'ID': 1597, 'Q1_OSAT': 10}),
#  Document(page_content='Everyone I speak with is always extremely pleasant and professional. I would recommend XXX to someone looking for a reliable bank . They always go out of there way to help you solve any issues are problems you might have.', metadata={'ID': 1615, 'Q1_OSAT': 10}),
#  Document(page_content='Candace was extremely helpful. She was pleasant and explained everything in detail.', metadata={'ID': 1620, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1621, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1657, 'Q1_OSAT': 8}),
#  Document(page_content='nan', metadata={'ID': 1664, 'Q1_OSAT': 10}),
#  Document(page_content='Knowledgeable, friendly staff', metadata={'ID': 1697, 'Q1_OSAT': 10}),
#  Document(page_content='I was extremely pleased with the info I received. My plan will be even easier to complete, than I had thought.', metadata={'ID': 1702, 'Q1_OSAT': 10}),
#  Document(page_content='Great Customer Service', metadata={'ID': 1705, 'Q1_OSAT': 10}),
#  Document(page_content='I believe I should be able to cancel a automatic withdraw without cancelling my card and getting a new one when a business or charity will not cooperate.', metadata={'ID': 1728, 'Q1_OSAT': 3}),
#  Document(page_content='Wait time to talk was brief and the rep was very polite, knowledgeable and resolved the issue quickly.', metadata={'ID': 1734, 'Q1_OSAT': 10}),
#  Document(page_content='Helped guide me thru the process. She was very patient.', metadata={'ID': 1763, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1772, 'Q1_OSAT': 10}),
#  Document(page_content='Great person on the phone! Pleasant', metadata={'ID': 1776, 'Q1_OSAT': 10}),
#  Document(page_content='My question was answered.', metadata={'ID': 1779, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1805, 'Q1_OSAT': 10}),
#  Document(page_content='I MADE A MISTAKE ABOUT A DEPOSIT I THOUGH I HAD MADE. THE AGENT I WAS WORKING WITH HELD HER GROUND AND SHOWED ME THAT I MUST BE WRONG. AT THE TIME I THOUGH SHE WAS WRONG. I LATER FOUND MY "MY DEPOSIT" IN MY WALLET. GOOD FOR XXX NOT GIVING IN.', metadata={'ID': 1815, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1822, 'Q1_OSAT': 10}),
#  Document(page_content='Daisy was Polite and knowledgeable . She answered all my questions.', metadata={'ID': 1826, 'Q1_OSAT': 10}),
#  Document(page_content='I received fast and kind service when I needed an international wire.', metadata={'ID': 1828, 'Q1_OSAT': 10}),
#  Document(page_content='The l.Andy who answered was kind and clear.', metadata={'ID': 1829, 'Q1_OSAT': 10}),
#  Document(page_content='The individual I talked with was very Helpful and provided answers to all of my questions.', metadata={'ID': 1843, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1864, 'Q1_OSAT': 10}),
#  Document(page_content='i was very happy', metadata={'ID': 1872, 'Q1_OSAT': 10}),
#  Document(page_content='I had to leave a voicemail message and I actually received the call back very quickly!!', metadata={'ID': 1895, 'Q1_OSAT': 10}),
#  Document(page_content='explanation was viable. Solution is to be done.', metadata={'ID': 1907, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1916, 'Q1_OSAT': 10}),
#  Document(page_content='Excellent, knowledgeable service. Quick', metadata={'ID': 1948, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 1963, 'Q1_OSAT': 10}),
#  Document(page_content='Good customer service', metadata={'ID': 1993, 'Q1_OSAT': 10}),
#  Document(page_content='All I had to do was call the number that was listed along with the amount that was taking money from checking account.', metadata={'ID': 2002, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2011, 'Q1_OSAT': 9}),
#  Document(page_content='nan', metadata={'ID': 2024, 'Q1_OSAT': 9}),
#  Document(page_content='nan', metadata={'ID': 2048, 'Q1_OSAT': 9}),
#  Document(page_content='nan', metadata={'ID': 2066, 'Q1_OSAT': 1}),
#  Document(page_content='Very friendly and answered all my questions', metadata={'ID': 2074, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2077, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2078, 'Q1_OSAT': 9}),
#  Document(page_content='nan', metadata={'ID': 2084, 'Q1_OSAT': 10}),
#  Document(page_content='Answered my questions and helped me resolve my issue.', metadata={'ID': 2085, 'Q1_OSAT': 10}),
#  Document(page_content='Excellent customer service', metadata={'ID': 2097, 'Q1_OSAT': 10}),
#  Document(page_content='The person I talked to was so patient and helpful. Was able to solve my problems for me.', metadata={'ID': 2099, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2103, 'Q1_OSAT': 9}),
#  Document(page_content='Good', metadata={'ID': 2125, 'Q1_OSAT': 8}),
#  Document(page_content='Good', metadata={'ID': 2126, 'Q1_OSAT': 7}),
#  Document(page_content='As always, the XXX customer service person was very helpful, very efficient, very friendly and addressed the reason for my call 100% to my satisfaction. XXX has a great staff, and theyâ€™re easy to reach. Keep doing what youâ€™re doing!', metadata={'ID': 2128, 'Q1_OSAT': 10}),
#  Document(page_content='You folks ALWAYS make it easy when I call with a question or issue! Katie was amazingly helpful yesterday, and took care of things in a wonderfully professional manner, without being impersonal. Give her a raise! :-)', metadata={'ID': 2154, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2169, 'Q1_OSAT': 10}),
#  Document(page_content='She was able to help me with my problem', metadata={'ID': 2173, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2178, 'Q1_OSAT': 10}),
#  Document(page_content='Not sure the information I was given is right.', metadata={'ID': 2187, 'Q1_OSAT': 7}),
#  Document(page_content='nan', metadata={'ID': 2190, 'Q1_OSAT': 6}),
#  Document(page_content='Great call no problems helpful individual', metadata={'ID': 2195, 'Q1_OSAT': 10}),
#  Document(page_content='An excellent job by a professional', metadata={'ID': 2196, 'Q1_OSAT': 10}),
#  Document(page_content='Efficient & pleasant & time efficient too', metadata={'ID': 2198, 'Q1_OSAT': 10}),
#  Document(page_content='The person to whom I talked was knowledgeable and sympathetic. She rates a 9.5-10. HOWEVER, the banks policy on holding checks is ludicrous-- especially since the check in question came from the same source that has been giving me checks once per month for the past 8.5 years and has NEVER ONCE bounced. I was charged a courtesy fee of $30, due to insufficient funds, even though I had almost $2,000 being held. You got the interest on my money that you were holding, but I got a courtesy fee! Unbelievable!', metadata={'ID': 2199, 'Q1_OSAT': 8}),
#  Document(page_content='Stellar customer service. Needed my limit raised to make a cashier check in Sarasota and the representative accomplished that quickly', metadata={'ID': 2201, 'Q1_OSAT': 10}),
#  Document(page_content="The 2 employee's I spoke with were extremely friendly, and very helpful!", metadata={'ID': 2202, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2213, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2220, 'Q1_OSAT': 9}),
#  Document(page_content='The person that I dealt with was very Professional and Courteous! I have been a Customer since the early 1980â€™s and never had a problem with any of your staff! Keep Up the Great Work!', metadata={'ID': 2225, 'Q1_OSAT': 10}),
#  Document(page_content="Answer did not resolve our tenant's problem but was exactly correct and the agent provided additional useful suggestions.", metadata={'ID': 2232, 'Q1_OSAT': 9}),
#  Document(page_content='Agent answered my questions and anticipated my needs. She seemed very knowledgeable and did not just read a script!', metadata={'ID': 2233, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2269, 'Q1_OSAT': 10}),
#  Document(page_content='Knowledge Agent', metadata={'ID': 2270, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2286, 'Q1_OSAT': 8}),
#  Document(page_content='nan', metadata={'ID': 2291, 'Q1_OSAT': 10}),
#  Document(page_content='Very helpful agent. Harland Clark is messing up when one orders checks. Enter one order & says you entered two orders? Called Harlan Clark. Robo answering. Disconnected 3 times. Finally gir to a human being at Harland Clark. "Oh, not to worry. You entered only one order. System is messing up."', metadata={'ID': 2303, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2314, 'Q1_OSAT': 10}),
#  Document(page_content='Personable XXX representative.', metadata={'ID': 2317, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2338, 'Q1_OSAT': 8}),
#  Document(page_content='nan', metadata={'ID': 2343, 'Q1_OSAT': 10}),
#  Document(page_content='I had a question about a CD from Ent which I wanted to set up', metadata={'ID': 2344, 'Q1_OSAT': 10}),
#  Document(page_content='I spoke to an unusually pleasant and helpful employee who showed a high degree of patience with my questions and a similar degree of knowledge in helping me.', metadata={'ID': 2360, 'Q1_OSAT': 10}),
#  Document(page_content='Efficient and customer friendly', metadata={'ID': 2365, 'Q1_OSAT': 10}),
#  Document(page_content='Immediate customer service from Chris; immediate results', metadata={'ID': 2366, 'Q1_OSAT': 10}),
#  Document(page_content='I always find everyone at the XXX to be knowledgeable, Courteous and helpful.', metadata={'ID': 2367, 'Q1_OSAT': 10}),
#  Document(page_content='Polite prompt and bent over backwards to solve my issues. Gave me extremely information about using my XXX account at sister banks in 22408 where I am going to spend extended amount of time there to heal.', metadata={'ID': 2372, 'Q1_OSAT': 10}),
#  Document(page_content='Were outstanding and prompt in solving my dilemma.', metadata={'ID': 2373, 'Q1_OSAT': 10}),
#  Document(page_content='She was knowledgeable, kind and helpful', metadata={'ID': 2386, 'Q1_OSAT': 8}),
#  Document(page_content='I found my call to be quickly answered and the lady to be very polite and very friendly. I am always very pleased with the service I receive at Ent and I am a long time member. Thank you.', metadata={'ID': 2390, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2391, 'Q1_OSAT': 10}),
#  Document(page_content='The XXX representative was friendly, polite and answered all my concerns.', metadata={'ID': 2402, 'Q1_OSAT': 10}),
#  Document(page_content='Service was quick and staff was pleasant. They seemed happy to help me.', metadata={'ID': 2404, 'Q1_OSAT': 10}),
#  Document(page_content='Great customer service', metadata={'ID': 2408, 'Q1_OSAT': 10}),
#  Document(page_content='XXX Credit Union has the BEST most respectful and knowledgeable agents. It is always a pleasure to be on the phone with them!', metadata={'ID': 2428, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2436, 'Q1_OSAT': 9}),
#  Document(page_content='You guys just disabled my card because it had me using six months. You didnâ€™t buy her check if I did or not you just ***** take the card off so when I actually didnâ€™t need it, I wouldnâ€™t have a ***** using you *****.', metadata={'ID': 2445, 'Q1_OSAT': 2}),
#  Document(page_content='Always eager to help', metadata={'ID': 2473, 'Q1_OSAT': 10}),
#  Document(page_content='Quick response and took care of what I needed quickly.', metadata={'ID': 2474, 'Q1_OSAT': 10}),
#  Document(page_content='She was knowledgeable, efficient and polite. Answered my questions thoroughly and provided the info I needed.', metadata={'ID': 2477, 'Q1_OSAT': 10}),
#  Document(page_content='very courteous and knowledgeable', metadata={'ID': 2491, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2493, 'Q1_OSAT': 10}),
#  Document(page_content='The representative was helpful, kind and professional. They answered all my questions, ordered my new debit card, and added a travel note.', metadata={'ID': 2498, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2523, 'Q1_OSAT': 9}),
#  Document(page_content='nan', metadata={'ID': 2535, 'Q1_OSAT': 9}),
#  Document(page_content='person who i talked with helped me.', metadata={'ID': 2538, 'Q1_OSAT': 10}),
#  Document(page_content='There was very prompt attention to my issue. An investigator called me to tell me the issue was resolved and she was very professional and kind.', metadata={'ID': 2540, 'Q1_OSAT': 10}),
#  Document(page_content='Good service', metadata={'ID': 2553, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2558, 'Q1_OSAT': 10}),
#  Document(page_content='AJ understood the issue. She tried to have me call the number of your fraud reporting agency. I told her that there is no ability to speak to a human at that number, so she put me on hold and took care of the problem.', metadata={'ID': 2562, 'Q1_OSAT': 10}),
#  Document(page_content='Agent was able to help me right away.', metadata={'ID': 2569, 'Q1_OSAT': 10}),
#  Document(page_content='accurate, friendly courteous.', metadata={'ID': 2581, 'Q1_OSAT': 10}),
#  Document(page_content='was quick and answered reason for call.', metadata={'ID': 2583, 'Q1_OSAT': 10}),
#  Document(page_content='Kelly on the phone was very nice and the issue was resolved super quickly.', metadata={'ID': 2595, 'Q1_OSAT': 10}),
#  Document(page_content='I made two different calls on the same day, for different reasons. In one, I was able to easily accomplish what I needed very quickly. In the second, because I changed my current address in the first call, it delayed completing what I required, though the ultimate response was faster than expected.', metadata={'ID': 2613, 'Q1_OSAT': 9}),
#  Document(page_content='nan', metadata={'ID': 2623, 'Q1_OSAT': 8}),
#  Document(page_content='Very friendly Very very clean I never had problems for 40th years !', metadata={'ID': 2627, 'Q1_OSAT': 9}),
#  Document(page_content='Always courteous and extremely helpful.', metadata={'ID': 2642, 'Q1_OSAT': 10}),
#  Document(page_content='Pleasant and helpful to resolve inquiry debt charge from April..', metadata={'ID': 2647, 'Q1_OSAT': 10}),
#  Document(page_content='I needed to make a wire transfer and the customer service representative did a great job taking the information and submitting the wire transfer. Very professional and it was completed without any delays.', metadata={'ID': 2658, 'Q1_OSAT': 10}),
#  Document(page_content='I had an issue when buying a vehicle and was happy to have the problem sorted out quickly.', metadata={'ID': 2663, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2670, 'Q1_OSAT': 10}),
#  Document(page_content='total professional interface with the XXX call center', metadata={'ID': 2685, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2689, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2715, 'Q1_OSAT': 10}),
#  Document(page_content='about my Debit Card ! My Question was answered right away from a friendly Person', metadata={'ID': 2731, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2761, 'Q1_OSAT': 10}),
#  Document(page_content='This was the email I sent to the XXX Team that handed my dispute: ccgllc 07/13/2023 10:41 PM I am impressed with how quickly this was taken care of (and so relieved). My thanks to all XXX-CU reps that made this happen. ~ Caroline Gray', metadata={'ID': 2762, 'Q1_OSAT': 10}),
#  Document(page_content='(1) As always, I tell each XXX-CU customer service employee that helps me: "You are so well-trained, quick to respond, and patient. Thank you so much." I feel strongly about giving "well deserved" compliments. (2) Our conversations take "only as long as necessary" to discuss the issue at hand and come to a fair conclusion. (3) In so many ways today, it is hard to ask for help---but never with XXX-CU employees.', metadata={'ID': 2763, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2765, 'Q1_OSAT': 10}),
#  Document(page_content='Ben and Donnell were quite knowledgeable about the home equity line on credit loan I applied for. I was overwhelmed over all the new jargon. They explained what each unknown term was. I was apprehensive about the whole loan. Ben and Donnell helped me understand what was needed. I and my sweetheart of a significant other are completely satisfied with the process.', metadata={'ID': 2774, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2790, 'Q1_OSAT': 10}),
#  Document(page_content='Efficient service without a wait. Greeter and Teller knew what they were doing. Clean facility and friendly people!', metadata={'ID': 2792, 'Q1_OSAT': 10}),
#  Document(page_content='Friendly. Efficient. Knowledgeable.', metadata={'ID': 2804, 'Q1_OSAT': 10}),
#  Document(page_content='Representative was knowledgeable, professional, thorough, and pleasant to speak with. She answered all my questions.', metadata={'ID': 2806, 'Q1_OSAT': 10}),
#  Document(page_content='The individual who assisted me made sure the issue I was having in regards to a cashier check, was taken care of so I could accomplish my transaction. I couldnâ€™t have been more satisfied', metadata={'ID': 2820, 'Q1_OSAT': 10}),
#  Document(page_content='called three times. left message NO CALL BACK!!!', metadata={'ID': 2830, 'Q1_OSAT': 1}),
#  Document(page_content='My most recent interaction was with a supervisor via messaging from the online banking site. I explained how crucial it was to receive my debit card replacement,living in a very rural area in NC. I was sent my card far quicker than the estimated 2-4 weeks. That time frame is horrendous especially for members not living close to an XXX or a credit union in the system allowing use of their services Thru XXX. Anyway I am always happy and grateful That XXX values even the small customers such as myself.', metadata={'ID': 2832, 'Q1_OSAT': 10}),
#  Document(page_content='To find out if I could use my ATM card to withdraw cash while Iâ€™m traveling in Australia, New Zealand and Fiji in October.', metadata={'ID': 2858, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2897, 'Q1_OSAT': 9}),
#  Document(page_content='nan', metadata={'ID': 2902, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 2935, 'Q1_OSAT': 10}),
#  Document(page_content='Quick service friendly & complete satisfaction', metadata={'ID': 2989, 'Q1_OSAT': 10}),
#  Document(page_content='Great service. Always helpful.', metadata={'ID': 2993, 'Q1_OSAT': 10}),
#  Document(page_content='My question was answered and a solution was given! Thank you!', metadata={'ID': 2995, 'Q1_OSAT': 10}),
#  Document(page_content='Simply had a question about a check', metadata={'ID': 3005, 'Q1_OSAT': 10}),
#  Document(page_content='They answer the phone, and answered all of my questions', metadata={'ID': 3015, 'Q1_OSAT': 10}),
#  Document(page_content='Shame on you , I had previously told you I would pay, keep annoying me', metadata={'ID': 3027, 'Q1_OSAT': 1}),
#  Document(page_content='My information for my checks is still incorrect. I was sent faulty checks with the perforation on the wrong side and no one has tried to contact me to let me know whether they are or are not sending me new checks. This is creating financial implications for me.', metadata={'ID': 3035, 'Q1_OSAT': 2}),
#  Document(page_content='Lost debit card.', metadata={'ID': 3052, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 3063, 'Q1_OSAT': 10}),
#  Document(page_content='The friendly courteous service I received. Tiffany made me feel like I was her number one priority.', metadata={'ID': 3074, 'Q1_OSAT': 10}),
#  Document(page_content='I had an issue and it was quickly resolved.', metadata={'ID': 3075, 'Q1_OSAT': 10}),
#  Document(page_content='The representative who worked with me to resolve my issue was named Corey. He provided me with a resolution and gave me several suggestions for taking care of my problem.', metadata={'ID': 3124, 'Q1_OSAT': 10}),
#  Document(page_content='Costumer service very professional and understanding, thank you', metadata={'ID': 3131, 'Q1_OSAT': 9}),
#  Document(page_content='nan', metadata={'ID': 3146, 'Q1_OSAT': 8}),
#  Document(page_content='nan', metadata={'ID': 3147, 'Q1_OSAT': 8}),
#  Document(page_content='nan', metadata={'ID': 3155, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 3166, 'Q1_OSAT': 10}),
#  Document(page_content='very pleasent person to talk with and i got the direction that i needed.', metadata={'ID': 3178, 'Q1_OSAT': 10}),
#  Document(page_content='The banker was polite, professional, and handled my situation quickly by forwarding it to the appropriate department', metadata={'ID': 3179, 'Q1_OSAT': 10}),
#  Document(page_content='I absolutely love Ent they are always very helpful in a timely manner with my needs. Thank you', metadata={'ID': 3188, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 3200, 'Q1_OSAT': 8}),
#  Document(page_content='Nicole Green was helpful and informative.', metadata={'ID': 3243, 'Q1_OSAT': 10}),
#  Document(page_content='The reason for my score is because the person was very polite and followed through with my request. I enjoyed talking with her. So nice.', metadata={'ID': 3256, 'Q1_OSAT': 10}),
#  Document(page_content='I was significantly unhappy by the way I had been treated by the ELAN branch of the family. They have been unreasonably horrid in several contacts I and they have had over 8 to 10 months. A readjustment of organization and some personnel can not happen soon enough. I was distressed to be given what someone apparently believed was a true statement that they gave me about my account. It was not. I was made to feel like I was trying to do an ELAN culprit that I was trying to steel funds from ELAN when the true picture was that ELAN has been rather slovenly in how quickly they post the receipt of funds so that ELAN does not make unnecessary implied accusations against those of us who may experienced stresses in our lives.', metadata={'ID': 3259, 'Q1_OSAT': 10}),
#  Document(page_content='Agent thoroughly researched y account, address, and recent attempt by ssa to deposit.', metadata={'ID': 3277, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 3298, 'Q1_OSAT': 10}),
#  Document(page_content='Very friendly', metadata={'ID': 3299, 'Q1_OSAT': 10}),
#  Document(page_content='Agent was knowledgable.and answered all my questions', metadata={'ID': 3305, 'Q1_OSAT': 10}),
#  Document(page_content='Professional, courteous, polite, to the point, gave me all the information I needed, wished me a wonderful day!', metadata={'ID': 3314, 'Q1_OSAT': 10}),
#  Document(page_content='Had to get another debit card. Personal was outstanding and kind.', metadata={'ID': 3326, 'Q1_OSAT': 10}),
# ...
#  Document(page_content='Efficient, friendly & a good overall experience.', metadata={'ID': 9877, 'Q1_OSAT': 9}),
#  Document(page_content='Great friendly customer service never an issue with the Credit Unions', metadata={'ID': 9883, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 9885, 'Q1_OSAT': 10}),
#  Document(page_content='Ent employees heard my questions correctly and responded accurately and immediately', metadata={'ID': 9900, 'Q1_OSAT': 10}),
#  Document(page_content="She was able to answer my questions except if I'd lost my cashiers check what would i do to keep it from expiring?", metadata={'ID': 9922, 'Q1_OSAT': 9}),
#  Document(page_content='Representative was very helpful and got an appointment scheduled.', metadata={'ID': 9932, 'Q1_OSAT': 10}),
#  Document(page_content='Ent let someone cash a check dated 9/8/23 on 9/6/23 over drew my account. When I called was told my fault. Not cool', metadata={'ID': 9944, 'Q1_OSAT': 1}),
#  Document(page_content='All questions were answered', metadata={'ID': 9973, 'Q1_OSAT': 10}),
#  Document(page_content='customer was more than helpful', metadata={'ID': 9986, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 9992, 'Q1_OSAT': 10}),
#  Document(page_content='Customer service representative was very knowledgeable about helping me access my account, and was very friendly.', metadata={'ID': 9994, 'Q1_OSAT': 10}),
#  Document(page_content='I always have had great member service, there is always room for improvement with member service, attitudes and personalities. But I absolutely love XXX credit Union. Heck, I worked for The Credit Union for 7 years as well.', metadata={'ID': 10002, 'Q1_OSAT': 9}),
#  Document(page_content='She was patient, professional and friendly as well as being able to address all of my concerns. She gave me clear solutions and also left a note on my account, to help prevent any issues in the future.', metadata={'ID': 10013, 'Q1_OSAT': 10}),
#  Document(page_content='Representative was helpful and followed through on what they said they would do.', metadata={'ID': 10068, 'Q1_OSAT': 9}),
#  Document(page_content="I was able to complete a 3 way call with my Mom's bank so that her bank could wire me money. Rep was extremely helpful.", metadata={'ID': 10069, 'Q1_OSAT': 10}),
#  Document(page_content="There wasn't an answer call back next week", metadata={'ID': 10078, 'Q1_OSAT': 9}),
#  Document(page_content='VERY HELPFUL FIXED MY PROBLEM', metadata={'ID': 10088, 'Q1_OSAT': 10}),
#  Document(page_content='Transaction was quick and I received what I wanted.', metadata={'ID': 10102, 'Q1_OSAT': 9}),
#  Document(page_content='nan', metadata={'ID': 10106, 'Q1_OSAT': 10}),
#  Document(page_content="The credit union was very helpful in advising me on how to transfer my account's. Also when ever I call for assistance the person on the the end are very patient and explain procedures very clear. I would recommend Ent credit union to anyone want good service.", metadata={'ID': 10107, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10110, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10114, 'Q1_OSAT': 3}),
#  Document(page_content='nan', metadata={'ID': 10127, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10154, 'Q1_OSAT': 10}),
#  Document(page_content='I needed to update my insurance information since I have a new policy for the vehicle that I have a an XXX loan on. I was on hold for 20 minutes before I requested a call back. Iâ€™m still waiting more than 24 hours later.', metadata={'ID': 10156, 'Q1_OSAT': 5}),
#  Document(page_content='nan', metadata={'ID': 10161, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10163, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10168, 'Q1_OSAT': 8}),
#  Document(page_content='nan', metadata={'ID': 10172, 'Q1_OSAT': 10}),
#  Document(page_content='I called just asking about information about CDs and wound up being able to do the entire transaction over the phone.', metadata={'ID': 10177, 'Q1_OSAT': 10}),
#  Document(page_content='Because the issue I had was not of my doing, and I was talked to with compassion and understanding.', metadata={'ID': 10178, 'Q1_OSAT': 10}),
#  Document(page_content='Rep, stayed on the line with another credit union untill matters were settled!! Great ðŸ‘\x8d Service!!', metadata={'ID': 10180, 'Q1_OSAT': 10}),
#  Document(page_content='Had a question about money market account. Rep was friendly and very helpful. Answered all my questions in great detail.', metadata={'ID': 10186, 'Q1_OSAT': 10}),
#  Document(page_content='Fast and helpful', metadata={'ID': 10221, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10233, 'Q1_OSAT': 10}),
#  Document(page_content='They helped me so I can understand what I need to do', metadata={'ID': 10252, 'Q1_OSAT': 10}),
#  Document(page_content='Courtesy and prompt service', metadata={'ID': 10290, 'Q1_OSAT': 10}),
#  Document(page_content='The lady customer service was awesome. She answered my question and I was confident with her skills.', metadata={'ID': 10295, 'Q1_OSAT': 10}),
#  Document(page_content='Very attentive', metadata={'ID': 10313, 'Q1_OSAT': 10}),
#  Document(page_content='very helpful support and accomplished what I hoped to accomplish, plus was given support to also sign up for Ent Protect.', metadata={'ID': 10323, 'Q1_OSAT': 10}),
#  Document(page_content="Got my issue answered and feel confident the phishing won't be accessed.", metadata={'ID': 10328, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10331, 'Q1_OSAT': 10}),
#  Document(page_content='Good service. Your cute tellers.', metadata={'ID': 10334, 'Q1_OSAT': 9}),
#  Document(page_content='nan', metadata={'ID': 10365, 'Q1_OSAT': 10}),
#  Document(page_content='The customer service answered my call right away and very knowledgeable on contacts I needed to resolve my problem. I always have a good experience at XXX. I have been there for decades.', metadata={'ID': 10382, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10402, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10418, 'Q1_OSAT': 9}),
#  Document(page_content='nan', metadata={'ID': 10420, 'Q1_OSAT': 10}),
#  Document(page_content='was very polite and was able to answer my questions', metadata={'ID': 10422, 'Q1_OSAT': 10}),
#  Document(page_content='Very polite. Took care of the reason I called and asked if I needed help with anything else.', metadata={'ID': 10431, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10447, 'Q1_OSAT': 10}),
#  Document(page_content='Service was prompt and my question was answered after account verification.', metadata={'ID': 10459, 'Q1_OSAT': 8}),
#  Document(page_content='She was very friendly despite me being upset and she calmed me down and addressed all of my issues. She was personable and very professional.', metadata={'ID': 10462, 'Q1_OSAT': 10}),
#  Document(page_content='Great service, knowledgeable employees, polite, expansion and always updating safeguards in system.', metadata={'ID': 10470, 'Q1_OSAT': 9}),
#  Document(page_content='The person who helped me was knowledgeable and took care of my request quickly and efficiently. She is an access to XXX. Thank you!!!', metadata={'ID': 10475, 'Q1_OSAT': 10}),
#  Document(page_content='I was told that I would receive a call from a manger with 2 hours now it has been days and nobody called me back!', metadata={'ID': 10477, 'Q1_OSAT': 1}),
#  Document(page_content='I needed to know how to complete my account number for electronic funds transfers.', metadata={'ID': 10503, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10541, 'Q1_OSAT': 10}),
#  Document(page_content='Ent has been very good to me and helpful for many years was very happy when XXX was brought to Pueblo colorado .I used them in 90s in colo springs', metadata={'ID': 10551, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10554, 'Q1_OSAT': 10}),
#  Document(page_content='The lady I spoke with was so warm and welcoming to address my issue.', metadata={'ID': 10557, 'Q1_OSAT': 10}),
#  Document(page_content='The only downside was the time on hold', metadata={'ID': 10578, 'Q1_OSAT': 9}),
#  Document(page_content='Fast and helpful resolution.', metadata={'ID': 10588, 'Q1_OSAT': 10}),
#  Document(page_content='Na', metadata={'ID': 10608, 'Q1_OSAT': 6}),
#  Document(page_content='Great service quick', metadata={'ID': 10611, 'Q1_OSAT': 10}),
#  Document(page_content='I received the help I needed quickly, the customer representative was friendly and professional--they asked me about my day, and showed concern when I told them why I needed to up my daily limit (car repair, needed as a result of incident after visiting my mother).', metadata={'ID': 10617, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10619, 'Q1_OSAT': 10}),
#  Document(page_content="I got my question answered immediately. She was very knowledgeable and patient with me. She didn't hesitate to help me out. I always get great service at Ent, that's why I refer them to all of my friends and family.", metadata={'ID': 10632, 'Q1_OSAT': 10}),
#  Document(page_content="Always get great service inside the banks, BUT the call center folks need some training. They give us the wrong info. We have to inside to get our business taken care of. It's very frustrating.", metadata={'ID': 10633, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10637, 'Q1_OSAT': 9}),
#  Document(page_content='nan', metadata={'ID': 10652, 'Q1_OSAT': 10}),
#  Document(page_content='Inflexible consideration of reversal of NSF fees when timing of transferring within accounts is obvious when there is no historic abuse of funds.', metadata={'ID': 10678, 'Q1_OSAT': 1}),
#  Document(page_content='Gail was polite and helpful', metadata={'ID': 10679, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10680, 'Q1_OSAT': 1}),
#  Document(page_content='nan', metadata={'ID': 10696, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10728, 'Q1_OSAT': 8}),
#  Document(page_content='I appreciate the level of security taken by the representative I spoke to.', metadata={'ID': 10729, 'Q1_OSAT': 10}),
#  Document(page_content='They were understanding and listened to my concern. They were very quick to come up with a solution.', metadata={'ID': 10736, 'Q1_OSAT': 10}),
#  Document(page_content='Was a fraud case and the people I talked with was knowledgeable and friendly.', metadata={'ID': 10746, 'Q1_OSAT': 10}),
#  Document(page_content='Great customer service and very friendly associate on the phone at Ent. Very helpful and I appreciate his feedback. Thanks, R. P.', metadata={'ID': 10762, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10792, 'Q1_OSAT': 10}),
#  Document(page_content='not receiving statement', metadata={'ID': 10793, 'Q1_OSAT': 9}),
#  Document(page_content='They quickly and comprehensively answered my question.', metadata={'ID': 10808, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10817, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10838, 'Q1_OSAT': 5}),
#  Document(page_content='your employee was very courteous.', metadata={'ID': 10844, 'Q1_OSAT': 9}),
#  Document(page_content='Ent staff are always professional and helpful wether in person or on the phone.', metadata={'ID': 10845, 'Q1_OSAT': 10}),
#  Document(page_content='The usual helpful and professional call.', metadata={'ID': 10846, 'Q1_OSAT': 10}),
#  Document(page_content='Fast and efficient service.', metadata={'ID': 10847, 'Q1_OSAT': 10}),
#  Document(page_content='I called Ent to ask if they would provide a Notary Public for my Last Will and Testament, which they said they could doâ€¦..but was told that Ent couldnâ€™t provide any witnesses for this service. I visited another institution which didnâ€™t seem troubled to assist me with this.', metadata={'ID': 10849, 'Q1_OSAT': 5}),
#  Document(page_content='nan', metadata={'ID': 10880, 'Q1_OSAT': 10}),
#  Document(page_content='Customer service person was very nice, professional & was able to provide the answer to my question.', metadata={'ID': 10885, 'Q1_OSAT': 10}),
#  Document(page_content='Great customer service, patient with me and assisted me with my needs during the phone call.', metadata={'ID': 10894, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10895, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10897, 'Q1_OSAT': 9}),
#  Document(page_content='I needed to make a change in accounts, told your rep what I needed, he knew exactly what had to be done and did it.', metadata={'ID': 10947, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 10960, 'Q1_OSAT': 10}),
#  Document(page_content='staff always pleasant and helpful and knowledgeable', metadata={'ID': 10965, 'Q1_OSAT': 10}),
#  Document(page_content='You guys are the best im always happy with the service and appreciate your customer service and you guys always help me with all my needs', metadata={'ID': 10986, 'Q1_OSAT': 10}),
#  Document(page_content="I asked online if I was able to open a promotional CD without coming in in-person. The representative said no, but that I should call to discuss options. I called and this new representative also said no, no additional information per options offered. Why did the online representative tell me to call in the first place? Very silly. It wasn't the phone call representative's fault but it was annoying.", metadata={'ID': 11010, 'Q1_OSAT': 4}),
#  Document(page_content='The contact center was very condescending during the call. Treated us lime we were dumb and asked if we understood what a charge was. It was not a friendly call, more like you were going into battle.', metadata={'ID': 11011, 'Q1_OSAT': 3}),
#  Document(page_content='nan', metadata={'ID': 11016, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 11035, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 11036, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 11040, 'Q1_OSAT': 1}),
#  Document(page_content='Good service and very courtesies.', metadata={'ID': 11087, 'Q1_OSAT': 10}),
#  Document(page_content='I was hoping to open a checking account because we are moving back to Colorado springs in November but I understand that it is not possible.', metadata={'ID': 11089, 'Q1_OSAT': 2}),
#  Document(page_content='nan', metadata={'ID': 11113, 'Q1_OSAT': 10}),
#  Document(page_content='Nothing to complain about. All went well.', metadata={'ID': 11127, 'Q1_OSAT': 9}),
#  Document(page_content='nan', metadata={'ID': 11161, 'Q1_OSAT': 9}),
#  Document(page_content='nan', metadata={'ID': 11170, 'Q1_OSAT': 9}),
#  Document(page_content='nan', metadata={'ID': 11188, 'Q1_OSAT': 10}),
#  Document(page_content='I needed a one time increase on my debit card daily limit to cover roof repairs. They handled it immediately and the process was completed in a timely fashion.', metadata={'ID': 11194, 'Q1_OSAT': 10}),
#  Document(page_content='Quick and easy Lovely person', metadata={'ID': 11247, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 11255, 'Q1_OSAT': 10}),
#  Document(page_content='I called to change the due date of a personal loan and was able to do that without any complications.', metadata={'ID': 11273, 'Q1_OSAT': 10}),
#  Document(page_content='The guidance I received was superb. I have already solved my problem by following the guidance.', metadata={'ID': 11293, 'Q1_OSAT': 10}),
#  Document(page_content='Excellent job', metadata={'ID': 11308, 'Q1_OSAT': 10}),
#  Document(page_content='Every time I call XXX, the people I talk to are very polite and knowledgeable.', metadata={'ID': 11310, 'Q1_OSAT': 10}),
#  Document(page_content='nan', metadata={'ID': 11317, 'Q1_OSAT': 10}),
#  Document(page_content='Called first thing in the morning and the customer service rep was friendly and helped me refund a non-sufficient fund fee', metadata={'ID': 11328, 'Q1_OSAT': 10}),
#  ...]

# %% [markdown]
# ## 4. Embedding
# Change text into a vector, could be used to compare similarity

# %%
from langchain.embeddings import OpenAIEmbeddings

embedding_model = OpenAIEmbeddings()
text = "Hi It's time for skiing"
text_emdedding = embedding_model.embed_query(text)

print("Your embedding length: {}".format(len(text_emdedding)))
print("Samples: {} ...".format(text_emdedding[:5]))
# Out:
# Your embedding length: 1536
# Samples: [0.002953369864917754, 0.009271258475735903, -0.005900462615691105, -0.020576292621032808, -0.017073677829616826] ...

# %% [markdown]
# ## Vectorstore

# %%
from langchain.vectorstores import Chroma
from langchain.document_loaders import CSVLoader

loader = CSVLoader(file_path="../data/ms_sample.csv", encoding="utf-8"
                   , csv_args={'delimiter': ','})
data = loader.load()
# vectorstore = FAISS.from_documents(df_loader, embedding_model)

# %%
data
# Out:
# [Document(page_content='ID: 1\nQ1_OSAT: 10\nComments: Courteous people who seem to care about the customer', metadata={'source': '../data/ms_sample.csv', 'row': 0}),
#  Document(page_content='ID: 36\nQ1_OSAT: 10\nComments: My concern was handled quickly and professionally by a caring individual who was knowledgeable in the area of my needs. They asked if there was anything else they could do to assist me, but they had already solved my problem.', metadata={'source': '../data/ms_sample.csv', 'row': 1}),
#  Document(page_content='ID: 70\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 2}),
#  Document(page_content='ID: 107\nQ1_OSAT: 10\nComments: I had the GREATEST customer service and interaction with Deja!! She was very helpful and knowledgeable. She smiled and shook my hand.', metadata={'source': '../data/ms_sample.csv', 'row': 3}),
#  Document(page_content='ID: 111\nQ1_OSAT: 10\nComments: I felt someone was trying to trick me into giving personal info and saying they were from XXX. I did report it and I also hung up on this man.', metadata={'source': '../data/ms_sample.csv', 'row': 4}),
#  Document(page_content="ID: 120\nQ1_OSAT: 10\nComments: My issue which included transferring finds from one account to another's was easily managed with all security protocols. The XXX representative was friendly , personable, and professional. We also discussed a CD option. Great customer service.", metadata={'source': '../data/ms_sample.csv', 'row': 5}),
#  Document(page_content='ID: 123\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 6}),
#  Document(page_content='ID: 124\nQ1_OSAT: 10\nComments: My questions were answered.', metadata={'source': '../data/ms_sample.csv', 'row': 7}),
#  Document(page_content='ID: 132\nQ1_OSAT: 10\nComments: Rep was friendly, respectful,courteous and knowledgeable and answered my questions quickly and thoroughly. She immediately knew where to go to find the answer to the problem.', metadata={'source': '../data/ms_sample.csv', 'row': 8}),
#  Document(page_content='ID: 138\nQ1_OSAT: 6\nComments: We Never discussed where, in my accounts the credit line would be held or how I can access it. I called back with these questions. I felt like Mariah pushed me to answer questions immediately on the phone about specific financial totals off the top of my head without time to access documents. This may have worked against me. She was interested in closing the deal ASAP.', metadata={'source': '../data/ms_sample.csv', 'row': 9}),
#  Document(page_content='ID: 152\nQ1_OSAT: 10\nComments: My call was answered promptly - no hold even though it was first thing in the morning. My question about Bill Pay was answered quickly determining the date my payment went out to a credit card company. The technician who helped me even quickly provided a letter of proof of payment to send to the credit card company showing the bill was paid on time. This was all handled in a matter of minutes. Quick prompt efficient, and super kind service! Thank you', metadata={'source': '../data/ms_sample.csv', 'row': 10}),
#  Document(page_content='ID: 159\nQ1_OSAT: 10\nComments: I made the call to find out how to make an appointment with a representative at Jackson Creek. The Ent agent I spoke with guided me through the process on your website, I got my appointment, and left the call a happy member.', metadata={'source': '../data/ms_sample.csv', 'row': 11}),
#  Document(page_content='ID: 194\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 12}),
#  Document(page_content='ID: 200\nQ1_OSAT: 10\nComments: Quick answer to my question', metadata={'source': '../data/ms_sample.csv', 'row': 13}),
#  Document(page_content="ID: 202\nQ1_OSAT: 10\nComments: I usually have good experiences when i talk to Ent CU personnel. I haven't had occasion to be unhappy with Ent personnel that i can remember.", metadata={'source': '../data/ms_sample.csv', 'row': 14}),
#  Document(page_content='ID: 204\nQ1_OSAT: 10\nComments: To confirm wire transfer was received and instructions were followed.', metadata={'source': '../data/ms_sample.csv', 'row': 15}),
#  Document(page_content='ID: 255\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 16}),
#  Document(page_content='ID: 285\nQ1_OSAT: 10\nComments: person was helpful and polite and put me in contact with the people I needed to speak with', metadata={'source': '../data/ms_sample.csv', 'row': 17}),
#  Document(page_content='ID: 288\nQ1_OSAT: 10\nComments: Handle the situation for me and answered all my questions', metadata={'source': '../data/ms_sample.csv', 'row': 18}),
#  Document(page_content='ID: 295\nQ1_OSAT: 10\nComments: Customer rep I spoke with was very courteous and patient while assisting me with the questions I had. Also, made some great recommendations about my accounts.', metadata={'source': '../data/ms_sample.csv', 'row': 19}),
#  Document(page_content='ID: 303\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 20}),
#  Document(page_content="ID: 326\nQ1_OSAT: 10\nComments: Individual helped me figure out an issue. Was XXX's or was it T-Mobile's. With the information provided I was able to quickly identify that the issue was with T-mobile and was able to fix it.", metadata={'source': '../data/ms_sample.csv', 'row': 21}),
#  Document(page_content='ID: 328\nQ1_OSAT: 8\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 22}),
#  Document(page_content='ID: 335\nQ1_OSAT: 10\nComments: It was what I needed', metadata={'source': '../data/ms_sample.csv', 'row': 23}),
#  Document(page_content='ID: 344\nQ1_OSAT: 10\nComments: I received all the information I needed to make a really good decision on my account', metadata={'source': '../data/ms_sample.csv', 'row': 24}),
#  Document(page_content='ID: 347\nQ1_OSAT: 10\nComments: The amount I can transfer at one time.', metadata={'source': '../data/ms_sample.csv', 'row': 25}),
#  Document(page_content="ID: 354\nQ1_OSAT: 6\nComments: I was rushed during the phone call. Didn't take the time to listen to me.", metadata={'source': '../data/ms_sample.csv', 'row': 26}),
#  Document(page_content="ID: 361\nQ1_OSAT: 10\nComments: The rep was very helpful. I just needed info snout moving funds from my account to another XXX members account. I've done it and wasn't sure I could do it over the phone.", metadata={'source': '../data/ms_sample.csv', 'row': 27}),
#  Document(page_content='ID: 369\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 28}),
#  Document(page_content='ID: 393\nQ1_OSAT: 10\nComments: Whenever I call, everyone is so polite and always ready to help.', metadata={'source': '../data/ms_sample.csv', 'row': 29}),
#  Document(page_content='ID: 394\nQ1_OSAT: 10\nComments: The young lady on the phone was so polite. Rwilling to help me. With all my questions. And I really appreciate people that look out for the senior citizens. So thank you again it was a pleasure doing business with you', metadata={'source': '../data/ms_sample.csv', 'row': 30}),
#  Document(page_content='ID: 396\nQ1_OSAT: 10\nComments: Questions were answered quickly and accurately.', metadata={'source': '../data/ms_sample.csv', 'row': 31}),
#  Document(page_content='ID: 397\nQ1_OSAT: 10\nComments: Ent has always been great. They help in every way possible, no matter what the situation is.', metadata={'source': '../data/ms_sample.csv', 'row': 32}),
#  Document(page_content='ID: 413\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 33}),
#  Document(page_content='ID: 427\nQ1_OSAT: 10\nComments: I have been a member for a half century and have been extremely satisfied with the service', metadata={'source': '../data/ms_sample.csv', 'row': 34}),
#  Document(page_content='ID: 439\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 35}),
#  Document(page_content="ID: 456\nQ1_OSAT: 10\nComments: Direct access to an English speaking human. Simple solution to my problem. Constructive usage of my time. However, after 3 minutes more of my time to give you this rating. I don't like wasting my time further. Goodbye", metadata={'source': '../data/ms_sample.csv', 'row': 36}),
#  Document(page_content="ID: 472\nQ1_OSAT: 10\nComments: I called about a potential fraud charge and got that clarified very quickly. The attendant immediately put in a case for the charges and gave me an ETA for when they'll reach out about it later.", metadata={'source': '../data/ms_sample.csv', 'row': 37}),
#  Document(page_content='ID: 496\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 38}),
#  Document(page_content='ID: 505\nQ1_OSAT: 8\nComments: They couldnâ€™t find a Bank near me in Dayton Ohio to tx a check', metadata={'source': '../data/ms_sample.csv', 'row': 39}),
#  Document(page_content='ID: 539\nQ1_OSAT: 10\nComments: forgot my keys at the Canon City CO branch. The customer representative was extremely helpful in putting me in touch with the branch. Found my keys and they asked me several question to make sure the keys were mine,', metadata={'source': '../data/ms_sample.csv', 'row': 40}),
#  Document(page_content='ID: 540\nQ1_OSAT: 9\nComments: The customer rep was very knowledgable and kind.. She answered my concern very quickly. Unlike the last person I dealt with at the Canon office who was horribly patronizing!', metadata={'source': '../data/ms_sample.csv', 'row': 41}),
#  Document(page_content='ID: 555\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 42}),
#  Document(page_content='ID: 585\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 43}),
#  Document(page_content='ID: 587\nQ1_OSAT: 10\nComments: My question was answered promptly.', metadata={'source': '../data/ms_sample.csv', 'row': 44}),
#  Document(page_content='ID: 625\nQ1_OSAT: 10\nComments: Had a super detail oriented service member, walked through all the steps and even gave me great suggestions to help resolve the issue. Best credit union hands down', metadata={'source': '../data/ms_sample.csv', 'row': 45}),
#  Document(page_content='ID: 641\nQ1_OSAT: 10\nComments: Zach was extremely helpful, professional and pleasant to work with. He took care of the reason I called with efficiency and introduced a great perk for continuing doing business with Ent.', metadata={'source': '../data/ms_sample.csv', 'row': 46}),
#  Document(page_content='ID: 643\nQ1_OSAT: 9\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 47}),
#  Document(page_content='ID: 650\nQ1_OSAT: 10\nComments: Great customer service so compassionate, very understanding. Love iENT from the bottom of my heart.', metadata={'source': '../data/ms_sample.csv', 'row': 48}),
#  Document(page_content='ID: 660\nQ1_OSAT: 10\nComments: The representative was very knowledgeable and helpful. She understood what I wanted and took care of it.', metadata={'source': '../data/ms_sample.csv', 'row': 49}),
#  Document(page_content='ID: 666\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 50}),
#  Document(page_content='ID: 671\nQ1_OSAT: 10\nComments: Everyone was very helpful especially Jessica', metadata={'source': '../data/ms_sample.csv', 'row': 51}),
#  Document(page_content="ID: 679\nQ1_OSAT: 10\nComments: 'nice1 easy to talk", metadata={'source': '../data/ms_sample.csv', 'row': 52}),
#  Document(page_content='ID: 682\nQ1_OSAT: 9\nComments: Friendly, caring, knowledgeable', metadata={'source': '../data/ms_sample.csv', 'row': 53}),
#  Document(page_content="ID: 683\nQ1_OSAT: 8\nComments: The problem wasn't resolved but Suzanna tried!", metadata={'source': '../data/ms_sample.csv', 'row': 54}),
#  Document(page_content='ID: 729\nQ1_OSAT: 10\nComments: Every interaction with them is fabulous. Even living outside Colorado they are so easy to get ahold of and help resolved your issue as quickly as possible. Customer service is outstanding.', metadata={'source': '../data/ms_sample.csv', 'row': 55}),
#  Document(page_content='ID: 738\nQ1_OSAT: 10\nComments: Brian was friendly and did what I asked and verified it and gave me the balances of both accounts worked with. I also appreciated that he understood my passcode with no problems. I am almost always satisfied with the telephone employees at XXX.', metadata={'source': '../data/ms_sample.csv', 'row': 56}),
#  Document(page_content='ID: 739\nQ1_OSAT: 10\nComments: Paula was friendly and efficient', metadata={'source': '../data/ms_sample.csv', 'row': 57}),
#  Document(page_content="ID: 751\nQ1_OSAT: 3\nComments: Because sometimes I have no idea when a pending purchase will post, I got hit with three overdraft charges in one day. The lady was nice, but said there was nothing she could do to reverse $90 in charges. Left a bad taste in my mouth because I've been a customer for 8ish years, and am hitting a particularly low point financially.", metadata={'source': '../data/ms_sample.csv', 'row': 58}),
#  Document(page_content='ID: 755\nQ1_OSAT: 10\nComments: Got me to the correct person immediately.', metadata={'source': '../data/ms_sample.csv', 'row': 59}),
#  Document(page_content='ID: 759\nQ1_OSAT: 10\nComments: A very kind and caring gentleman named Sal, took care of all my concerns about a fraudulent charge. He reassured me that everything would be taken care of and was so nice concerning my entire situation. J Jones', metadata={'source': '../data/ms_sample.csv', 'row': 60}),
#  Document(page_content='ID: 760\nQ1_OSAT: 10\nComments: Caring, friendly, very efficient', metadata={'source': '../data/ms_sample.csv', 'row': 61}),
#  Document(page_content='ID: 765\nQ1_OSAT: 2\nComments: Be glad to: 7/26/2023, I called Ent Credit Union for information and help. I spoke with Christina. She said she will have Charleen call me back regarding my Updating Account Beneficiaries form and questions. She said Charleen will know more about it. She said she sent Charleen a message and she will contact me. Well, I am still waiting for this call/contact. Now I am considering if I should keep my account with Ent. I have been a loyal customer for many, many years and deserve better. I now know my little money means nothing to you but hoped my loyalty does. I am still waiting to hear from Ent regarding my situation. Yes, I am disappointed in the service. After all these years with Ent, this is sad. I was just thinking about starting an allotment to increase my account. Now I am considering if I should even keep the account with you and transfer my funds to a more supportive Credit Union.', metadata={'source': '../data/ms_sample.csv', 'row': 62}),
#  Document(page_content='ID: 783\nQ1_OSAT: 2\nComments: Agent was rude/unfriendly--in a bad mood', metadata={'source': '../data/ms_sample.csv', 'row': 63}),
#  Document(page_content='ID: 788\nQ1_OSAT: 8\nComments: Be more willing to lend!', metadata={'source': '../data/ms_sample.csv', 'row': 64}),
#  Document(page_content='ID: 789\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 65}),
#  Document(page_content='ID: 813\nQ1_OSAT: 9\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 66}),
#  Document(page_content='ID: 816\nQ1_OSAT: 9\nComments: Person I spoke with took time to explain my XXX mbrship in detail. I had no idea the difference between my XXX Visa card and my mbrship and funds I had no idea I had.', metadata={'source': '../data/ms_sample.csv', 'row': 67}),
#  Document(page_content='ID: 821\nQ1_OSAT: 10\nComments: I had to get a medallion signature and my questions were answered, and an appointment was made for within 24 hours.', metadata={'source': '../data/ms_sample.csv', 'row': 68}),
#  Document(page_content='ID: 822\nQ1_OSAT: 5\nComments: Representative was professionally and pleasant but not really answering my question', metadata={'source': '../data/ms_sample.csv', 'row': 69}),
#  Document(page_content='ID: 830\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 70}),
#  Document(page_content='ID: 839\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 71}),
#  Document(page_content='ID: 843\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 72}),
#  Document(page_content='ID: 862\nQ1_OSAT: 7\nComments: The individual I spoke with expressed concern for my conflict, and asked pertinent questions; however, the end result was not as expected, and after I made another inquiry, I have been ignored.', metadata={'source': '../data/ms_sample.csv', 'row': 73}),
#  Document(page_content='ID: 872\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 74}),
#  Document(page_content='ID: 874\nQ1_OSAT: 10\nComments: Extremely friendly, and given the information I needed', metadata={'source': '../data/ms_sample.csv', 'row': 75}),
#  Document(page_content='ID: 913\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 76}),
#  Document(page_content='ID: 922\nQ1_OSAT: 8\nComments: I was able to get my question answered and the situation resolved. Monica was really helpful giving me the advice I needed.', metadata={'source': '../data/ms_sample.csv', 'row': 77}),
#  Document(page_content='ID: 925\nQ1_OSAT: 9\nComments: The person I spoke with was polite and helpful. He knew how to fix the problem I was calling about and communicated clearly with me the timeline on how long it would take to be resolved.', metadata={'source': '../data/ms_sample.csv', 'row': 78}),
#  Document(page_content='ID: 948\nQ1_OSAT: 10\nComments: Excellent customer service', metadata={'source': '../data/ms_sample.csv', 'row': 79}),
#  Document(page_content='ID: 954\nQ1_OSAT: 10\nComments: The representative was friendly, helpful and efficient.', metadata={'source': '../data/ms_sample.csv', 'row': 80}),
#  Document(page_content='ID: 955\nQ1_OSAT: 10\nComments: the customer service representative was very helpful and was able to take care of all my needs asked her if she could order me my checks and also send me register log since l use my debit card 80 % if the time and post every time l use my card l have had my acct with XXX for 30+ years and am very happy with the service and that everytime l do need assistance the service staff know what their doing have never in all the years had a problem so thank you for the Best Service all these years', metadata={'source': '../data/ms_sample.csv', 'row': 81}),
#  Document(page_content='ID: 957\nQ1_OSAT: 6\nComments: I was able to access my safe deposit box which was my goal. However, I had to wait for another customer that had no key for their box. It had to be drilled so their issue caused me delay. They shouldâ€™ve made an appointment given their situation, I was told I could walk in without an appointment little did I know', metadata={'source': '../data/ms_sample.csv', 'row': 82}),
#  Document(page_content='ID: 959\nQ1_OSAT: 10\nComments: They were very helpful.', metadata={'source': '../data/ms_sample.csv', 'row': 83}),
#  Document(page_content='ID: 960\nQ1_OSAT: 10\nComments: The very nice lady that assisted me resolved the issues and got me on my way as fast as she could. It was an awesome experience!', metadata={'source': '../data/ms_sample.csv', 'row': 84}),
#  Document(page_content='ID: 970\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 85}),
#  Document(page_content='ID: 1011\nQ1_OSAT: 8\nComments: Very friendly member who answered the phone. Did her best to help me.', metadata={'source': '../data/ms_sample.csv', 'row': 86}),
#  Document(page_content='ID: 1026\nQ1_OSAT: 10\nComments: I am always made to feel as if I am your only customer. My contact did not rush me, explained everything and made sure I was good before ending the call.', metadata={'source': '../data/ms_sample.csv', 'row': 87}),
#  Document(page_content='ID: 1030\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 88}),
#  Document(page_content="ID: 1032\nQ1_OSAT: 8\nComments: I made a mistake during a time I had severe backache and wasn't thinking further than the pain, and I transferred some money from checking to savings to prevent Liberty from taking an early payment but forgot that I had written a very rare check for the DMV for my car registration. The DMV got my check quickly and cashed it before I remembered to put the money back, and not having an internet connection didn't help. I was helped by a nice woman but she couldn't waive the courtesy charge of $30.", metadata={'source': '../data/ms_sample.csv', 'row': 89}),
#  Document(page_content='ID: 1033\nQ1_OSAT: 10\nComments: Very friendly and patient with me because I am hard of hearing.', metadata={'source': '../data/ms_sample.csv', 'row': 90}),
#  Document(page_content='ID: 1035\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 91}),
#  Document(page_content='ID: 1036\nQ1_OSAT: 5\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 92}),
#  Document(page_content='ID: 1051\nQ1_OSAT: 10\nComments: Customer service was very clear and informative to my situation', metadata={'source': '../data/ms_sample.csv', 'row': 93}),
#  Document(page_content='ID: 1058\nQ1_OSAT: 8\nComments: I was attempting to gather the facts on a very rare NSF action. The paper record was not as clear and easy to understand as I had hoped. Once the facts were uncovered, the actions were adjusted appropriately and responsibly.', metadata={'source': '../data/ms_sample.csv', 'row': 94}),
#  Document(page_content='ID: 1061\nQ1_OSAT: 9\nComments: I am not kept waiting for lengthy periods before my call is answered. The agents are professional and my issues are resolved in one call, for the most part.', metadata={'source': '../data/ms_sample.csv', 'row': 95}),
#  Document(page_content='ID: 1064\nQ1_OSAT: 10\nComments: my question was resolved.', metadata={'source': '../data/ms_sample.csv', 'row': 96}),
#  Document(page_content='ID: 1085\nQ1_OSAT: 10\nComments: The agent seemed to be very knowledgeable. And answered all my questions. She was also very pleasant.', metadata={'source': '../data/ms_sample.csv', 'row': 97}),
#  Document(page_content='ID: 1086\nQ1_OSAT: 10\nComments: Patient and informed person on phone.', metadata={'source': '../data/ms_sample.csv', 'row': 98}),
#  Document(page_content='ID: 1109\nQ1_OSAT: 9\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 99}),
#  Document(page_content='ID: 1113\nQ1_OSAT: 8\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 100}),
#  Document(page_content='ID: 1185\nQ1_OSAT: 9\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 101}),
#  Document(page_content='ID: 1191\nQ1_OSAT: 10\nComments: Information about use of my account was provided', metadata={'source': '../data/ms_sample.csv', 'row': 102}),
#  Document(page_content='ID: 1199\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 103}),
#  Document(page_content='ID: 1200\nQ1_OSAT: 10\nComments: The rep was extremely friendly, bubbly, upbeat, empathetic, personable and basically had all the traits every company should look for in their customer service employees. Ironically, she wasnâ€™t able to help me due to ENTâ€™s NSF policy, but she still made me happy.', metadata={'source': '../data/ms_sample.csv', 'row': 104}),
#  Document(page_content='ID: 1216\nQ1_OSAT: 10\nComments: In VERY little time, I was connected with a knowledgeable, capable person who understood my problem immediately and gave me clear, correct instructions on how to do what needed to be done--and it turns out that Ent had already built in an extraordinarily easy way to do it right from my account page!', metadata={'source': '../data/ms_sample.csv', 'row': 105}),
#  Document(page_content='ID: 1218\nQ1_OSAT: 10\nComments: The Channel one that helped me with very polite and listen to what I had to say and found where the mistake was.', metadata={'source': '../data/ms_sample.csv', 'row': 106}),
#  Document(page_content='ID: 1219\nQ1_OSAT: 10\nComments: The service was amazing', metadata={'source': '../data/ms_sample.csv', 'row': 107}),
#  Document(page_content='ID: 1220\nQ1_OSAT: 1\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 108}),
#  Document(page_content='ID: 1233\nQ1_OSAT: 10\nComments: all people I talk to are courteous and knowledgeable to my concerns', metadata={'source': '../data/ms_sample.csv', 'row': 109}),
#  Document(page_content='ID: 1238\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 110}),
#  Document(page_content='ID: 1252\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 111}),
#  Document(page_content='ID: 1267\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 112}),
#  Document(page_content='ID: 1270\nQ1_OSAT: 10\nComments: Destiny only took a couple of minutes to figure out why and explained to me why a deposit was rejected.', metadata={'source': '../data/ms_sample.csv', 'row': 113}),
#  Document(page_content='ID: 1276\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 114}),
#  Document(page_content='ID: 1284\nQ1_OSAT: 10\nComments: My wife has been a member of XXX for 35 years and we have always a terrific dealings with them. The service professionals are kind, gracious and helpful. As far as we are concerned, XXX will be our Credit Union for life.', metadata={'source': '../data/ms_sample.csv', 'row': 115}),
#  Document(page_content='ID: 1285\nQ1_OSAT: 10\nComments: The person was helpful. That was especially true in contrast to the previous person I called, who was not helpful at all!', metadata={'source': '../data/ms_sample.csv', 'row': 116}),
#  Document(page_content='ID: 1302\nQ1_OSAT: 10\nComments: Great service', metadata={'source': '../data/ms_sample.csv', 'row': 117}),
#  Document(page_content='ID: 1304\nQ1_OSAT: 10\nComments: She was pleasant and patient.Very helpful.', metadata={'source': '../data/ms_sample.csv', 'row': 118}),
#  Document(page_content='ID: 1307\nQ1_OSAT: 10\nComments: Very helpful and a willingness to resolve my problem.', metadata={'source': '../data/ms_sample.csv', 'row': 119}),
#  Document(page_content='ID: 1315\nQ1_OSAT: 10\nComments: When I call in the help line people have quick responses, great attitudes. when i have left messages for the loan department they are quick with call backs. in the loan dept better sugestions have been brought to my attention on better ways to go about things.', metadata={'source': '../data/ms_sample.csv', 'row': 120}),
#  Document(page_content='ID: 1324\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 121}),
#  Document(page_content='ID: 1336\nQ1_OSAT: 2\nComments: 24 hours later I have received no call and no action on my account.', metadata={'source': '../data/ms_sample.csv', 'row': 122}),
#  Document(page_content='ID: 1337\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 123}),
#  Document(page_content='ID: 1346\nQ1_OSAT: 10\nComments: Everytime I call in with a problem it always get solved :)', metadata={'source': '../data/ms_sample.csv', 'row': 124}),
#  Document(page_content="ID: 1355\nQ1_OSAT: 1\nComments: I appear to be getting a run-around about two missing deposits, each $1500. I was told by XXX to collect and provide a Electronic Trace Number for the two missing deposits. I called Ent and gave them the trace numbers and was told that XXX could not confirm that XXX received the two deposits. The person that I spoke with at XXX was unsure how to locate the details about the missing deposits and put me on hold several times to confirm with a co-worker. The source of the two deposits confirmed that XXX had received them. It appears that XXX received the two deposits and deposited them, but not my account. I'm out $3000 and staff at XXX so far has given me a run-round and each time reports that I need to collect something else.", metadata={'source': '../data/ms_sample.csv', 'row': 125}),
#  Document(page_content='ID: 1361\nQ1_OSAT: 10\nComments: Employeeâ€™s are always courteous and helpful', metadata={'source': '../data/ms_sample.csv', 'row': 126}),
#  Document(page_content='ID: 1394\nQ1_OSAT: 10\nComments: Customerservices', metadata={'source': '../data/ms_sample.csv', 'row': 127}),
#  Document(page_content='ID: 1407\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 128}),
#  Document(page_content='ID: 1413\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 129}),
#  Document(page_content='ID: 1423\nQ1_OSAT: 6\nComments: Too long on hold for a simple answer that is not on the website.', metadata={'source': '../data/ms_sample.csv', 'row': 130}),
#  Document(page_content='ID: 1424\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 131}),
#  Document(page_content='ID: 1428\nQ1_OSAT: 10\nComments: The customer service person was very professional', metadata={'source': '../data/ms_sample.csv', 'row': 132}),
#  Document(page_content='ID: 1438\nQ1_OSAT: 1\nComments: The policy that XXX seems to have when a customer wants to redeem a CD that is maturing is unreasonable. A request to have a check sent to the customer was denied.Very hard to understand and not customer service.', metadata={'source': '../data/ms_sample.csv', 'row': 133}),
#  Document(page_content='ID: 1451\nQ1_OSAT: 10\nComments: I had an issue with my credit/debit card and was able to get resolved quickly and to my satisfaction.', metadata={'source': '../data/ms_sample.csv', 'row': 134}),
#  Document(page_content='ID: 1459\nQ1_OSAT: 8\nComments: I got most of the information that I requested.', metadata={'source': '../data/ms_sample.csv', 'row': 135}),
#  Document(page_content='ID: 1460\nQ1_OSAT: 10\nComments: Person was knowledgeable and patient', metadata={'source': '../data/ms_sample.csv', 'row': 136}),
#  Document(page_content='ID: 1464\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 137}),
#  Document(page_content='ID: 1467\nQ1_OSAT: 5\nComments: There was an issue and once transferred the call went dead, happened twice. Finally, I got someone to not transfer without making sure the other side was there.', metadata={'source': '../data/ms_sample.csv', 'row': 138}),
#  Document(page_content='ID: 1472\nQ1_OSAT: 8\nComments: While everyone was helpful and friendly, my call got dropped once and I had to call back in and explain everything to a new person. I waited a few min to see if the first person would call back, but they did not.', metadata={'source': '../data/ms_sample.csv', 'row': 139}),
#  Document(page_content='ID: 1473\nQ1_OSAT: 10\nComments: i was extremely satisfied when I needed, not only a Medallion Stamp, but, a Notary stamp. This young man who works in the Broomfield, CO Credit Union took care of everything!.. And, in minutes!! I love this credit union.. they are always a caring staff. Thank you!', metadata={'source': '../data/ms_sample.csv', 'row': 140}),
#  Document(page_content="ID: 1477\nQ1_OSAT: 4\nComments: I live in Florida and to get a new debt card if stolen or destroyed it takes 10 to fourteen days or pay 50 dollars for Express delivery I know people who have credit union outside of Florida who don't have this problem", metadata={'source': '../data/ms_sample.csv', 'row': 141}),
#  Document(page_content='ID: 1481\nQ1_OSAT: 10\nComments: She was kind, she did a good job trying to solve my problems dns eek information to provide that could be helpful. She laughed a few times to lighten the mood- I was impressed, despite not fully getting the answer I wanted- she was gifted at saying no in a way I could tolerate.', metadata={'source': '../data/ms_sample.csv', 'row': 142}),
#  Document(page_content='ID: 1492\nQ1_OSAT: 10\nComments: Amazing service', metadata={'source': '../data/ms_sample.csv', 'row': 143}),
#  Document(page_content='ID: 1493\nQ1_OSAT: 10\nComments: They fixed my issue!', metadata={'source': '../data/ms_sample.csv', 'row': 144}),
#  Document(page_content='ID: 1512\nQ1_OSAT: 5\nComments: Phone rep. came across as condescending.', metadata={'source': '../data/ms_sample.csv', 'row': 145}),
#  Document(page_content="ID: 1513\nQ1_OSAT: 10\nComments: The customer service is always excellent. I wasn't on hold for a long time and the person who answered the call was pleasant and helpful.", metadata={'source': '../data/ms_sample.csv', 'row': 146}),
#  Document(page_content='ID: 1556\nQ1_OSAT: 10\nComments: Quick, competent service', metadata={'source': '../data/ms_sample.csv', 'row': 147}),
#  Document(page_content='ID: 1571\nQ1_OSAT: 8\nComments: The problem was not resolved.', metadata={'source': '../data/ms_sample.csv', 'row': 148}),
#  Document(page_content='ID: 1589\nQ1_OSAT: 10\nComments: My questions were answered.', metadata={'source': '../data/ms_sample.csv', 'row': 149}),
#  Document(page_content='ID: 1596\nQ1_OSAT: 9\nComments: I waited almost 30 minutes to get my new debit card after I saw the casher.', metadata={'source': '../data/ms_sample.csv', 'row': 150}),
#  Document(page_content='ID: 1597\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 151}),
#  Document(page_content='ID: 1615\nQ1_OSAT: 10\nComments: Everyone I speak with is always extremely pleasant and professional. I would recommend XXX to someone looking for a reliable bank . They always go out of there way to help you solve any issues are problems you might have.', metadata={'source': '../data/ms_sample.csv', 'row': 152}),
#  Document(page_content='ID: 1620\nQ1_OSAT: 10\nComments: Candace was extremely helpful. She was pleasant and explained everything in detail.', metadata={'source': '../data/ms_sample.csv', 'row': 153}),
#  Document(page_content='ID: 1621\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 154}),
#  Document(page_content='ID: 1657\nQ1_OSAT: 8\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 155}),
#  Document(page_content='ID: 1664\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 156}),
#  Document(page_content='ID: 1697\nQ1_OSAT: 10\nComments: Knowledgeable, friendly staff', metadata={'source': '../data/ms_sample.csv', 'row': 157}),
#  Document(page_content='ID: 1702\nQ1_OSAT: 10\nComments: I was extremely pleased with the info I received. My plan will be even easier to complete, than I had thought.', metadata={'source': '../data/ms_sample.csv', 'row': 158}),
#  Document(page_content='ID: 1705\nQ1_OSAT: 10\nComments: Great Customer Service', metadata={'source': '../data/ms_sample.csv', 'row': 159}),
#  Document(page_content='ID: 1728\nQ1_OSAT: 3\nComments: I believe I should be able to cancel a automatic withdraw without cancelling my card and getting a new one when a business or charity will not cooperate.', metadata={'source': '../data/ms_sample.csv', 'row': 160}),
#  Document(page_content='ID: 1734\nQ1_OSAT: 10\nComments: Wait time to talk was brief and the rep was very polite, knowledgeable and resolved the issue quickly.', metadata={'source': '../data/ms_sample.csv', 'row': 161}),
#  Document(page_content='ID: 1763\nQ1_OSAT: 10\nComments: Helped guide me thru the process. She was very patient.', metadata={'source': '../data/ms_sample.csv', 'row': 162}),
#  Document(page_content='ID: 1772\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 163}),
#  Document(page_content='ID: 1776\nQ1_OSAT: 10\nComments: Great person on the phone! Pleasant', metadata={'source': '../data/ms_sample.csv', 'row': 164}),
#  Document(page_content='ID: 1779\nQ1_OSAT: 10\nComments: My question was answered.', metadata={'source': '../data/ms_sample.csv', 'row': 165}),
#  Document(page_content='ID: 1805\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 166}),
#  Document(page_content='ID: 1815\nQ1_OSAT: 10\nComments: I MADE A MISTAKE ABOUT A DEPOSIT I THOUGH I HAD MADE. THE AGENT I WAS WORKING WITH HELD HER GROUND AND SHOWED ME THAT I MUST BE WRONG. AT THE TIME I THOUGH SHE WAS WRONG. I LATER FOUND MY "MY DEPOSIT" IN MY WALLET. GOOD FOR XXX NOT GIVING IN.', metadata={'source': '../data/ms_sample.csv', 'row': 167}),
#  Document(page_content='ID: 1822\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 168}),
#  Document(page_content='ID: 1826\nQ1_OSAT: 10\nComments: Daisy was Polite and knowledgeable . She answered all my questions.', metadata={'source': '../data/ms_sample.csv', 'row': 169}),
#  Document(page_content='ID: 1828\nQ1_OSAT: 10\nComments: I received fast and kind service when I needed an international wire.', metadata={'source': '../data/ms_sample.csv', 'row': 170}),
#  Document(page_content='ID: 1829\nQ1_OSAT: 10\nComments: The l.Andy who answered was kind and clear.', metadata={'source': '../data/ms_sample.csv', 'row': 171}),
#  Document(page_content='ID: 1843\nQ1_OSAT: 10\nComments: The individual I talked with was very Helpful and provided answers to all of my questions.', metadata={'source': '../data/ms_sample.csv', 'row': 172}),
#  Document(page_content='ID: 1864\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 173}),
#  Document(page_content='ID: 1872\nQ1_OSAT: 10\nComments: i was very happy', metadata={'source': '../data/ms_sample.csv', 'row': 174}),
#  Document(page_content='ID: 1895\nQ1_OSAT: 10\nComments: I had to leave a voicemail message and I actually received the call back very quickly!!', metadata={'source': '../data/ms_sample.csv', 'row': 175}),
#  Document(page_content='ID: 1907\nQ1_OSAT: 10\nComments: explanation was viable. Solution is to be done.', metadata={'source': '../data/ms_sample.csv', 'row': 176}),
#  Document(page_content='ID: 1916\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 177}),
#  Document(page_content='ID: 1948\nQ1_OSAT: 10\nComments: Excellent, knowledgeable service. Quick', metadata={'source': '../data/ms_sample.csv', 'row': 178}),
#  Document(page_content='ID: 1963\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 179}),
#  Document(page_content='ID: 1993\nQ1_OSAT: 10\nComments: Good customer service', metadata={'source': '../data/ms_sample.csv', 'row': 180}),
#  Document(page_content='ID: 2002\nQ1_OSAT: 10\nComments: All I had to do was call the number that was listed along with the amount that was taking money from checking account.', metadata={'source': '../data/ms_sample.csv', 'row': 181}),
#  Document(page_content='ID: 2011\nQ1_OSAT: 9\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 182}),
#  Document(page_content='ID: 2024\nQ1_OSAT: 9\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 183}),
#  Document(page_content='ID: 2048\nQ1_OSAT: 9\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 184}),
#  Document(page_content='ID: 2066\nQ1_OSAT: 1\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 185}),
#  Document(page_content='ID: 2074\nQ1_OSAT: 10\nComments: Very friendly and answered all my questions', metadata={'source': '../data/ms_sample.csv', 'row': 186}),
#  Document(page_content='ID: 2077\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 187}),
#  Document(page_content='ID: 2078\nQ1_OSAT: 9\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 188}),
#  Document(page_content='ID: 2084\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 189}),
#  Document(page_content='ID: 2085\nQ1_OSAT: 10\nComments: Answered my questions and helped me resolve my issue.', metadata={'source': '../data/ms_sample.csv', 'row': 190}),
#  Document(page_content='ID: 2097\nQ1_OSAT: 10\nComments: Excellent customer service', metadata={'source': '../data/ms_sample.csv', 'row': 191}),
#  Document(page_content='ID: 2099\nQ1_OSAT: 10\nComments: The person I talked to was so patient and helpful. Was able to solve my problems for me.', metadata={'source': '../data/ms_sample.csv', 'row': 192}),
#  Document(page_content='ID: 2103\nQ1_OSAT: 9\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 193}),
#  Document(page_content='ID: 2125\nQ1_OSAT: 8\nComments: Good', metadata={'source': '../data/ms_sample.csv', 'row': 194}),
#  Document(page_content='ID: 2126\nQ1_OSAT: 7\nComments: Good', metadata={'source': '../data/ms_sample.csv', 'row': 195}),
#  Document(page_content='ID: 2128\nQ1_OSAT: 10\nComments: As always, the XXX customer service person was very helpful, very efficient, very friendly and addressed the reason for my call 100% to my satisfaction. XXX has a great staff, and theyâ€™re easy to reach. Keep doing what youâ€™re doing!', metadata={'source': '../data/ms_sample.csv', 'row': 196}),
#  Document(page_content='ID: 2154\nQ1_OSAT: 10\nComments: You folks ALWAYS make it easy when I call with a question or issue! Katie was amazingly helpful yesterday, and took care of things in a wonderfully professional manner, without being impersonal. Give her a raise! :-)', metadata={'source': '../data/ms_sample.csv', 'row': 197}),
#  Document(page_content='ID: 2169\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 198}),
#  Document(page_content='ID: 2173\nQ1_OSAT: 10\nComments: She was able to help me with my problem', metadata={'source': '../data/ms_sample.csv', 'row': 199}),
#  Document(page_content='ID: 2178\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 200}),
#  Document(page_content='ID: 2187\nQ1_OSAT: 7\nComments: Not sure the information I was given is right.', metadata={'source': '../data/ms_sample.csv', 'row': 201}),
#  Document(page_content='ID: 2190\nQ1_OSAT: 6\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 202}),
#  Document(page_content='ID: 2195\nQ1_OSAT: 10\nComments: Great call no problems helpful individual', metadata={'source': '../data/ms_sample.csv', 'row': 203}),
#  Document(page_content='ID: 2196\nQ1_OSAT: 10\nComments: An excellent job by a professional', metadata={'source': '../data/ms_sample.csv', 'row': 204}),
#  Document(page_content='ID: 2198\nQ1_OSAT: 10\nComments: Efficient & pleasant & time efficient too', metadata={'source': '../data/ms_sample.csv', 'row': 205}),
#  Document(page_content='ID: 2199\nQ1_OSAT: 8\nComments: The person to whom I talked was knowledgeable and sympathetic. She rates a 9.5-10. HOWEVER, the banks policy on holding checks is ludicrous-- especially since the check in question came from the same source that has been giving me checks once per month for the past 8.5 years and has NEVER ONCE bounced. I was charged a courtesy fee of $30, due to insufficient funds, even though I had almost $2,000 being held. You got the interest on my money that you were holding, but I got a courtesy fee! Unbelievable!', metadata={'source': '../data/ms_sample.csv', 'row': 206}),
#  Document(page_content='ID: 2201\nQ1_OSAT: 10\nComments: Stellar customer service. Needed my limit raised to make a cashier check in Sarasota and the representative accomplished that quickly', metadata={'source': '../data/ms_sample.csv', 'row': 207}),
#  Document(page_content="ID: 2202\nQ1_OSAT: 10\nComments: The 2 employee's I spoke with were extremely friendly, and very helpful!", metadata={'source': '../data/ms_sample.csv', 'row': 208}),
#  Document(page_content='ID: 2213\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 209}),
#  Document(page_content='ID: 2220\nQ1_OSAT: 9\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 210}),
#  Document(page_content='ID: 2225\nQ1_OSAT: 10\nComments: The person that I dealt with was very Professional and Courteous! I have been a Customer since the early 1980â€™s and never had a problem with any of your staff! Keep Up the Great Work!', metadata={'source': '../data/ms_sample.csv', 'row': 211}),
#  Document(page_content="ID: 2232\nQ1_OSAT: 9\nComments: Answer did not resolve our tenant's problem but was exactly correct and the agent provided additional useful suggestions.", metadata={'source': '../data/ms_sample.csv', 'row': 212}),
#  Document(page_content='ID: 2233\nQ1_OSAT: 10\nComments: Agent answered my questions and anticipated my needs. She seemed very knowledgeable and did not just read a script!', metadata={'source': '../data/ms_sample.csv', 'row': 213}),
#  Document(page_content='ID: 2269\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 214}),
#  Document(page_content='ID: 2270\nQ1_OSAT: 10\nComments: Knowledge Agent', metadata={'source': '../data/ms_sample.csv', 'row': 215}),
#  Document(page_content='ID: 2286\nQ1_OSAT: 8\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 216}),
#  Document(page_content='ID: 2291\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 217}),
#  Document(page_content='ID: 2303\nQ1_OSAT: 10\nComments: Very helpful agent. Harland Clark is messing up when one orders checks. Enter one order & says you entered two orders? Called Harlan Clark. Robo answering. Disconnected 3 times. Finally gir to a human being at Harland Clark. "Oh, not to worry. You entered only one order. System is messing up."', metadata={'source': '../data/ms_sample.csv', 'row': 218}),
#  Document(page_content='ID: 2314\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 219}),
#  Document(page_content='ID: 2317\nQ1_OSAT: 10\nComments: Personable XXX representative.', metadata={'source': '../data/ms_sample.csv', 'row': 220}),
#  Document(page_content='ID: 2338\nQ1_OSAT: 8\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 221}),
#  Document(page_content='ID: 2343\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 222}),
#  Document(page_content='ID: 2344\nQ1_OSAT: 10\nComments: I had a question about a CD from Ent which I wanted to set up', metadata={'source': '../data/ms_sample.csv', 'row': 223}),
#  Document(page_content='ID: 2360\nQ1_OSAT: 10\nComments: I spoke to an unusually pleasant and helpful employee who showed a high degree of patience with my questions and a similar degree of knowledge in helping me.', metadata={'source': '../data/ms_sample.csv', 'row': 224}),
#  Document(page_content='ID: 2365\nQ1_OSAT: 10\nComments: Efficient and customer friendly', metadata={'source': '../data/ms_sample.csv', 'row': 225}),
#  Document(page_content='ID: 2366\nQ1_OSAT: 10\nComments: Immediate customer service from Chris; immediate results', metadata={'source': '../data/ms_sample.csv', 'row': 226}),
#  Document(page_content='ID: 2367\nQ1_OSAT: 10\nComments: I always find everyone at the XXX to be knowledgeable, Courteous and helpful.', metadata={'source': '../data/ms_sample.csv', 'row': 227}),
#  Document(page_content='ID: 2372\nQ1_OSAT: 10\nComments: Polite prompt and bent over backwards to solve my issues. Gave me extremely information about using my XXX account at sister banks in 22408 where I am going to spend extended amount of time there to heal.', metadata={'source': '../data/ms_sample.csv', 'row': 228}),
#  Document(page_content='ID: 2373\nQ1_OSAT: 10\nComments: Were outstanding and prompt in solving my dilemma.', metadata={'source': '../data/ms_sample.csv', 'row': 229}),
#  Document(page_content='ID: 2386\nQ1_OSAT: 8\nComments: She was knowledgeable, kind and helpful', metadata={'source': '../data/ms_sample.csv', 'row': 230}),
#  Document(page_content='ID: 2390\nQ1_OSAT: 10\nComments: I found my call to be quickly answered and the lady to be very polite and very friendly. I am always very pleased with the service I receive at Ent and I am a long time member. Thank you.', metadata={'source': '../data/ms_sample.csv', 'row': 231}),
#  Document(page_content='ID: 2391\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 232}),
#  Document(page_content='ID: 2402\nQ1_OSAT: 10\nComments: The XXX representative was friendly, polite and answered all my concerns.', metadata={'source': '../data/ms_sample.csv', 'row': 233}),
#  Document(page_content='ID: 2404\nQ1_OSAT: 10\nComments: Service was quick and staff was pleasant. They seemed happy to help me.', metadata={'source': '../data/ms_sample.csv', 'row': 234}),
# ...
#  Document(page_content='ID: 10221\nQ1_OSAT: 10\nComments: Fast and helpful', metadata={'source': '../data/ms_sample.csv', 'row': 912}),
#  Document(page_content='ID: 10233\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 913}),
#  Document(page_content='ID: 10252\nQ1_OSAT: 10\nComments: They helped me so I can understand what I need to do', metadata={'source': '../data/ms_sample.csv', 'row': 914}),
#  Document(page_content='ID: 10290\nQ1_OSAT: 10\nComments: Courtesy and prompt service', metadata={'source': '../data/ms_sample.csv', 'row': 915}),
#  Document(page_content='ID: 10295\nQ1_OSAT: 10\nComments: The lady customer service was awesome. She answered my question and I was confident with her skills.', metadata={'source': '../data/ms_sample.csv', 'row': 916}),
#  Document(page_content='ID: 10313\nQ1_OSAT: 10\nComments: Very attentive', metadata={'source': '../data/ms_sample.csv', 'row': 917}),
#  Document(page_content='ID: 10323\nQ1_OSAT: 10\nComments: very helpful support and accomplished what I hoped to accomplish, plus was given support to also sign up for Ent Protect.', metadata={'source': '../data/ms_sample.csv', 'row': 918}),
#  Document(page_content="ID: 10328\nQ1_OSAT: 10\nComments: Got my issue answered and feel confident the phishing won't be accessed.", metadata={'source': '../data/ms_sample.csv', 'row': 919}),
#  Document(page_content='ID: 10331\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 920}),
#  Document(page_content='ID: 10334\nQ1_OSAT: 9\nComments: Good service. Your cute tellers.', metadata={'source': '../data/ms_sample.csv', 'row': 921}),
#  Document(page_content='ID: 10365\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 922}),
#  Document(page_content='ID: 10382\nQ1_OSAT: 10\nComments: The customer service answered my call right away and very knowledgeable on contacts I needed to resolve my problem. I always have a good experience at XXX. I have been there for decades.', metadata={'source': '../data/ms_sample.csv', 'row': 923}),
#  Document(page_content='ID: 10402\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 924}),
#  Document(page_content='ID: 10418\nQ1_OSAT: 9\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 925}),
#  Document(page_content='ID: 10420\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 926}),
#  Document(page_content='ID: 10422\nQ1_OSAT: 10\nComments: was very polite and was able to answer my questions', metadata={'source': '../data/ms_sample.csv', 'row': 927}),
#  Document(page_content='ID: 10431\nQ1_OSAT: 10\nComments: Very polite. Took care of the reason I called and asked if I needed help with anything else.', metadata={'source': '../data/ms_sample.csv', 'row': 928}),
#  Document(page_content='ID: 10447\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 929}),
#  Document(page_content='ID: 10459\nQ1_OSAT: 8\nComments: Service was prompt and my question was answered after account verification.', metadata={'source': '../data/ms_sample.csv', 'row': 930}),
#  Document(page_content='ID: 10462\nQ1_OSAT: 10\nComments: She was very friendly despite me being upset and she calmed me down and addressed all of my issues. She was personable and very professional.', metadata={'source': '../data/ms_sample.csv', 'row': 931}),
#  Document(page_content='ID: 10470\nQ1_OSAT: 9\nComments: Great service, knowledgeable employees, polite, expansion and always updating safeguards in system.', metadata={'source': '../data/ms_sample.csv', 'row': 932}),
#  Document(page_content='ID: 10475\nQ1_OSAT: 10\nComments: The person who helped me was knowledgeable and took care of my request quickly and efficiently. She is an access to XXX. Thank you!!!', metadata={'source': '../data/ms_sample.csv', 'row': 933}),
#  Document(page_content='ID: 10477\nQ1_OSAT: 1\nComments: I was told that I would receive a call from a manger with 2 hours now it has been days and nobody called me back!', metadata={'source': '../data/ms_sample.csv', 'row': 934}),
#  Document(page_content='ID: 10503\nQ1_OSAT: 10\nComments: I needed to know how to complete my account number for electronic funds transfers.', metadata={'source': '../data/ms_sample.csv', 'row': 935}),
#  Document(page_content='ID: 10541\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 936}),
#  Document(page_content='ID: 10551\nQ1_OSAT: 10\nComments: Ent has been very good to me and helpful for many years was very happy when XXX was brought to Pueblo colorado .I used them in 90s in colo springs', metadata={'source': '../data/ms_sample.csv', 'row': 937}),
#  Document(page_content='ID: 10554\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 938}),
#  Document(page_content='ID: 10557\nQ1_OSAT: 10\nComments: The lady I spoke with was so warm and welcoming to address my issue.', metadata={'source': '../data/ms_sample.csv', 'row': 939}),
#  Document(page_content='ID: 10578\nQ1_OSAT: 9\nComments: The only downside was the time on hold', metadata={'source': '../data/ms_sample.csv', 'row': 940}),
#  Document(page_content='ID: 10588\nQ1_OSAT: 10\nComments: Fast and helpful resolution.', metadata={'source': '../data/ms_sample.csv', 'row': 941}),
#  Document(page_content='ID: 10608\nQ1_OSAT: 6\nComments: Na', metadata={'source': '../data/ms_sample.csv', 'row': 942}),
#  Document(page_content='ID: 10611\nQ1_OSAT: 10\nComments: Great service quick', metadata={'source': '../data/ms_sample.csv', 'row': 943}),
#  Document(page_content='ID: 10617\nQ1_OSAT: 10\nComments: I received the help I needed quickly, the customer representative was friendly and professional--they asked me about my day, and showed concern when I told them why I needed to up my daily limit (car repair, needed as a result of incident after visiting my mother).', metadata={'source': '../data/ms_sample.csv', 'row': 944}),
#  Document(page_content='ID: 10619\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 945}),
#  Document(page_content="ID: 10632\nQ1_OSAT: 10\nComments: I got my question answered immediately. She was very knowledgeable and patient with me. She didn't hesitate to help me out. I always get great service at Ent, that's why I refer them to all of my friends and family.", metadata={'source': '../data/ms_sample.csv', 'row': 946}),
#  Document(page_content="ID: 10633\nQ1_OSAT: 10\nComments: Always get great service inside the banks, BUT the call center folks need some training. They give us the wrong info. We have to inside to get our business taken care of. It's very frustrating.", metadata={'source': '../data/ms_sample.csv', 'row': 947}),
#  Document(page_content='ID: 10637\nQ1_OSAT: 9\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 948}),
#  Document(page_content='ID: 10652\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 949}),
#  Document(page_content='ID: 10678\nQ1_OSAT: 1\nComments: Inflexible consideration of reversal of NSF fees when timing of transferring within accounts is obvious when there is no historic abuse of funds.', metadata={'source': '../data/ms_sample.csv', 'row': 950}),
#  Document(page_content='ID: 10679\nQ1_OSAT: 10\nComments: Gail was polite and helpful', metadata={'source': '../data/ms_sample.csv', 'row': 951}),
#  Document(page_content='ID: 10680\nQ1_OSAT: 1\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 952}),
#  Document(page_content='ID: 10696\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 953}),
#  Document(page_content='ID: 10728\nQ1_OSAT: 8\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 954}),
#  Document(page_content='ID: 10729\nQ1_OSAT: 10\nComments: I appreciate the level of security taken by the representative I spoke to.', metadata={'source': '../data/ms_sample.csv', 'row': 955}),
#  Document(page_content='ID: 10736\nQ1_OSAT: 10\nComments: They were understanding and listened to my concern. They were very quick to come up with a solution.', metadata={'source': '../data/ms_sample.csv', 'row': 956}),
#  Document(page_content='ID: 10746\nQ1_OSAT: 10\nComments: Was a fraud case and the people I talked with was knowledgeable and friendly.', metadata={'source': '../data/ms_sample.csv', 'row': 957}),
#  Document(page_content='ID: 10762\nQ1_OSAT: 10\nComments: Great customer service and very friendly associate on the phone at Ent. Very helpful and I appreciate his feedback. Thanks, R. P.', metadata={'source': '../data/ms_sample.csv', 'row': 958}),
#  Document(page_content='ID: 10792\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 959}),
#  Document(page_content='ID: 10793\nQ1_OSAT: 9\nComments: not receiving statement', metadata={'source': '../data/ms_sample.csv', 'row': 960}),
#  Document(page_content='ID: 10808\nQ1_OSAT: 10\nComments: They quickly and comprehensively answered my question.', metadata={'source': '../data/ms_sample.csv', 'row': 961}),
#  Document(page_content='ID: 10817\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 962}),
#  Document(page_content='ID: 10838\nQ1_OSAT: 5\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 963}),
#  Document(page_content='ID: 10844\nQ1_OSAT: 9\nComments: your employee was very courteous.', metadata={'source': '../data/ms_sample.csv', 'row': 964}),
#  Document(page_content='ID: 10845\nQ1_OSAT: 10\nComments: Ent staff are always professional and helpful wether in person or on the phone.', metadata={'source': '../data/ms_sample.csv', 'row': 965}),
#  Document(page_content='ID: 10846\nQ1_OSAT: 10\nComments: The usual helpful and professional call.', metadata={'source': '../data/ms_sample.csv', 'row': 966}),
#  Document(page_content='ID: 10847\nQ1_OSAT: 10\nComments: Fast and efficient service.', metadata={'source': '../data/ms_sample.csv', 'row': 967}),
#  Document(page_content='ID: 10849\nQ1_OSAT: 5\nComments: I called Ent to ask if they would provide a Notary Public for my Last Will and Testament, which they said they could doâ€¦..but was told that Ent couldnâ€™t provide any witnesses for this service. I visited another institution which didnâ€™t seem troubled to assist me with this.', metadata={'source': '../data/ms_sample.csv', 'row': 968}),
#  Document(page_content='ID: 10880\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 969}),
#  Document(page_content='ID: 10885\nQ1_OSAT: 10\nComments: Customer service person was very nice, professional & was able to provide the answer to my question.', metadata={'source': '../data/ms_sample.csv', 'row': 970}),
#  Document(page_content='ID: 10894\nQ1_OSAT: 10\nComments: Great customer service, patient with me and assisted me with my needs during the phone call.', metadata={'source': '../data/ms_sample.csv', 'row': 971}),
#  Document(page_content='ID: 10895\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 972}),
#  Document(page_content='ID: 10897\nQ1_OSAT: 9\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 973}),
#  Document(page_content='ID: 10947\nQ1_OSAT: 10\nComments: I needed to make a change in accounts, told your rep what I needed, he knew exactly what had to be done and did it.', metadata={'source': '../data/ms_sample.csv', 'row': 974}),
#  Document(page_content='ID: 10960\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 975}),
#  Document(page_content='ID: 10965\nQ1_OSAT: 10\nComments: staff always pleasant and helpful and knowledgeable', metadata={'source': '../data/ms_sample.csv', 'row': 976}),
#  Document(page_content='ID: 10986\nQ1_OSAT: 10\nComments: You guys are the best im always happy with the service and appreciate your customer service and you guys always help me with all my needs', metadata={'source': '../data/ms_sample.csv', 'row': 977}),
#  Document(page_content="ID: 11010\nQ1_OSAT: 4\nComments: I asked online if I was able to open a promotional CD without coming in in-person. The representative said no, but that I should call to discuss options. I called and this new representative also said no, no additional information per options offered. Why did the online representative tell me to call in the first place? Very silly. It wasn't the phone call representative's fault but it was annoying.", metadata={'source': '../data/ms_sample.csv', 'row': 978}),
#  Document(page_content='ID: 11011\nQ1_OSAT: 3\nComments: The contact center was very condescending during the call. Treated us lime we were dumb and asked if we understood what a charge was. It was not a friendly call, more like you were going into battle.', metadata={'source': '../data/ms_sample.csv', 'row': 979}),
#  Document(page_content='ID: 11016\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 980}),
#  Document(page_content='ID: 11035\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 981}),
#  Document(page_content='ID: 11036\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 982}),
#  Document(page_content='ID: 11040\nQ1_OSAT: 1\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 983}),
#  Document(page_content='ID: 11087\nQ1_OSAT: 10\nComments: Good service and very courtesies.', metadata={'source': '../data/ms_sample.csv', 'row': 984}),
#  Document(page_content='ID: 11089\nQ1_OSAT: 2\nComments: I was hoping to open a checking account because we are moving back to Colorado springs in November but I understand that it is not possible.', metadata={'source': '../data/ms_sample.csv', 'row': 985}),
#  Document(page_content='ID: 11113\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 986}),
#  Document(page_content='ID: 11127\nQ1_OSAT: 9\nComments: Nothing to complain about. All went well.', metadata={'source': '../data/ms_sample.csv', 'row': 987}),
#  Document(page_content='ID: 11161\nQ1_OSAT: 9\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 988}),
#  Document(page_content='ID: 11170\nQ1_OSAT: 9\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 989}),
#  Document(page_content='ID: 11188\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 990}),
#  Document(page_content='ID: 11194\nQ1_OSAT: 10\nComments: I needed a one time increase on my debit card daily limit to cover roof repairs. They handled it immediately and the process was completed in a timely fashion.', metadata={'source': '../data/ms_sample.csv', 'row': 991}),
#  Document(page_content='ID: 11247\nQ1_OSAT: 10\nComments: Quick and easy Lovely person', metadata={'source': '../data/ms_sample.csv', 'row': 992}),
#  Document(page_content='ID: 11255\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 993}),
#  Document(page_content='ID: 11273\nQ1_OSAT: 10\nComments: I called to change the due date of a personal loan and was able to do that without any complications.', metadata={'source': '../data/ms_sample.csv', 'row': 994}),
#  Document(page_content='ID: 11293\nQ1_OSAT: 10\nComments: The guidance I received was superb. I have already solved my problem by following the guidance.', metadata={'source': '../data/ms_sample.csv', 'row': 995}),
#  Document(page_content='ID: 11308\nQ1_OSAT: 10\nComments: Excellent job', metadata={'source': '../data/ms_sample.csv', 'row': 996}),
#  Document(page_content='ID: 11310\nQ1_OSAT: 10\nComments: Every time I call XXX, the people I talk to are very polite and knowledgeable.', metadata={'source': '../data/ms_sample.csv', 'row': 997}),
#  Document(page_content='ID: 11317\nQ1_OSAT: 10\nComments: ', metadata={'source': '../data/ms_sample.csv', 'row': 998}),
#  Document(page_content='ID: 11328\nQ1_OSAT: 10\nComments: Called first thing in the morning and the customer service rep was friendly and helped me refund a non-sufficient fund fee', metadata={'source': '../data/ms_sample.csv', 'row': 999}),
#  ...]

# %%
vectorstore = Chroma.from_documents(data, embedding_model)

retriever = vectorstore.as_retriever()

# %% [markdown]
# ## Retriever

# %%
def format_docs(docs):
    return "\n\n".join([d.page_content for d in docs])

docs = format_docs(data)

# %%
from langchain.chains.combine_documents.stuff import StuffDocumentsChain
from langchain.chains.llm import LLMChain
from langchain.prompts import PromptTemplate

# Define prompt
prompt_template = """Write a concise summary of the following:
"{text}"
CONCISE SUMMARY:"""
prompt = PromptTemplate.from_template(prompt_template)

# Define LLM chain
llm = ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo-16k")
llm_chain = LLMChain(llm=llm, prompt=prompt)

# Define StuffDocumentsChain
stuff_chain = StuffDocumentsChain(llm_chain=llm_chain, document_variable_name="text")


print(stuff_chain.run(docs))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 19
#      15 # Define StuffDocumentsChain
#      16 stuff_chain = StuffDocumentsChain(llm_chain=llm_chain, document_variable_name="text")
# ---> 19 print(stuff_chain.run(docs))
#
# File ~/anaconda3/lib/python3.9/site-packages/langchain/chains/base.py:507, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     505     if len(args) != 1:
#     506         raise ValueError("`run` supports only one positional argument.")
# --> 507     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     508         _output_key
#     509     ]
#     511 if kwargs and not args:
#     512     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     513         _output_key
#     514     ]
#
# File ~/anaconda3/lib/python3.9/site-packages/langchain/chains/base.py:312, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     310 except BaseException as e:
#     311     run_manager.on_chain_error(e)
# --> 312     raise e
#     313 run_manager.on_chain_end(outputs)
#     314 final_outputs: Dict[str, Any] = self.prep_outputs(
#     315     inputs, outputs, return_only_outputs
#     316 )
#
# File ~/anaconda3/lib/python3.9/site-packages/langchain/chains/base.py:306, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     299 run_manager = callback_manager.on_chain_start(
#     300     dumpd(self),
#     301     inputs,
#     302     name=run_name,
#     303 )
#     304 try:
#     305     outputs = (
# --> 306         self._call(inputs, run_manager=run_manager)
#     307         if new_arg_supported
#     308         else self._call(inputs)
#     309     )
#     310 except BaseException as e:
#     311     run_manager.on_chain_error(e)
#
# File ~/anaconda3/lib/python3.9/site-packages/langchain/chains/combine_documents/base.py:123, in BaseCombineDocumentsChain._call(self, inputs, run_manager)
#     121 # Other keys are assumed to be needed for LLM prediction
#     122 other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 123 output, extra_return_dict = self.combine_docs(
#     124     docs, callbacks=_run_manager.get_child(), **other_keys
#     125 )
#     126 extra_return_dict[self.output_key] = output
#     127 return extra_return_dict
#
# File ~/anaconda3/lib/python3.9/site-packages/langchain/chains/combine_documents/stuff.py:170, in StuffDocumentsChain.combine_docs(self, docs, callbacks, **kwargs)
#     156 def combine_docs(
#     157     self, docs: List[Document], callbacks: Callbacks = None, **kwargs: Any
#     158 ) -> Tuple[str, dict]:
#     159     """Stuff all documents into one prompt and pass to LLM.
#     160
#     161     Args:
#    (...)
#     168         element returned is a dictionary of other keys to return.
#     169     """
# --> 170     inputs = self._get_inputs(docs, **kwargs)
#     171     # Call predict on the LLM.
#     172     return self.llm_chain.predict(callbacks=callbacks, **inputs), {}
#
# File ~/anaconda3/lib/python3.9/site-packages/langchain/chains/combine_documents/stuff.py:126, in StuffDocumentsChain._get_inputs(self, docs, **kwargs)
#     111 """Construct inputs from kwargs and docs.
#     112
#     113 Format and the join all the documents together into one input with name
#    (...)
#     123     dictionary of inputs to LLMChain
#     124 """
#     125 # Format each document according to the prompt
# --> 126 doc_strings = [format_document(doc, self.document_prompt) for doc in docs]
#     127 # Join the documents together to put them in the prompt.
#     128 inputs = {
#     129     k: v
#     130     for k, v in kwargs.items()
#     131     if k in self.llm_chain.prompt.input_variables
#     132 }
#
# File ~/anaconda3/lib/python3.9/site-packages/langchain/chains/combine_documents/stuff.py:126, in <listcomp>(.0)
#     111 """Construct inputs from kwargs and docs.
#     112
#     113 Format and the join all the documents together into one input with name
#    (...)
#     123     dictionary of inputs to LLMChain
#     124 """
#     125 # Format each document according to the prompt
# --> 126 doc_strings = [format_document(doc, self.document_prompt) for doc in docs]
#     127 # Join the documents together to put them in the prompt.
#     128 inputs = {
#     129     k: v
#     130     for k, v in kwargs.items()
#     131     if k in self.llm_chain.prompt.input_variables
#     132 }
#
# File ~/anaconda3/lib/python3.9/site-packages/langchain_core/prompts/base.py:248, in format_document(doc, prompt)
#     214 def format_document(doc: Document, prompt: BasePromptTemplate) -> str:
#     215     """Format a document into a string based on a prompt template.
#     216
#     217     First, this pulls information from the document from two sources:
#    (...)
#     246             >>> "Page 1: This is a joke"
#     247     """
# --> 248     base_info = {"page_content": doc.page_content, **doc.metadata}
#     249     missing_metadata = set(prompt.input_variables).difference(base_info)
#     250     if len(missing_metadata) > 0:
#
# AttributeError: 'str' object has no attribute 'page_content'

# %%
chain({"question":"how many reponses in this data, a response is identified by a unique ID", "chat_history":""})
# Out:
# {'question': 'how many reponses in this data, a response is identified by a unique ID',
#  'chat_history': '',
#  'answer': 'There are 4 responses in this data. Each response is identified by a unique ID.'}
